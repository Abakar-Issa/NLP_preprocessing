# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1L9JLLQHPZoMRwzYfmKcyM9VME_SHeZrr)

# %% [markdown]
# # Pre-processing texts
#
# Pre-process textual data using NLTK and Spacy.
#
# Within a computer, text is encoded as a string of characters.
# In order to analyze textual data within NLP applications, we first need to properly preprocess it.
# An NLP preprocessing pipeline generally consists of the following steps :
# * sentence segmentation
# * tokenisation
# * normalization: lower-casing, lemmatization, optionally removing stop-words and punctuation
# * pos-tagging
# * named entity recognition
# * parsing
#
# The first two steps are necessary, while the others are optional.
#
# For these exercises, we will use the modules **NLTK** and **spacy** (already installed on google colab, but some libraries might be missing for your NLTK, we'll see later).
#
# NLTK and Spacy both provide ways to carry out tasks such as segmentation, tokenization, lemmatization and pos-tagging.
#
# NLTK is a rather old library, but still used a lot. NLTK was built by scholars and researchers as a tool to help you create complex NLP functions.
# Spacy is more recent one, it implements an NLP pipeline. While NLTK provides access to many algorithms to get something done, spaCy provides the best way to do it (https://www.activestate.com/blog/natural-language-processing-nltk-vs-spacy/).
#
# We will extract information from Wikipedia pages as an example.

# %% [markdown]
# ## 0- Upload and read the text files
#
# At first, we're going to use a text written in English. Then, we'll try to apply the tools to French.
# We'll use the wikipedia library to extract pages from wikipedia

# %%
! pip install wikipedia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wikipedia) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2022.9.24)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=4f15d766c2074d8b2b5bce4cb12f74a8e2701b65e6ba5c5f6dcc69470b8788b0
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
import wikipedia
wikipedia.set_lang('en')
text_en = wikipedia.page("Lovelace")
print(text_en.content[:1000])
# Out:
# Augusta Ada King, Countess of Lovelace (née Byron; 10 December 1815 – 27 November 1852) was an English mathematician and writer, chiefly known for her work on Charles Babbage's proposed mechanical general-purpose computer, the Analytical Engine. She was the first to recognise that the machine had applications beyond pure calculation, and to have published the first algorithm intended to be carried out by such a machine. As a result, she is often regarded as the first computer programmer.Ada Byron was the only legitimate child of poet Lord Byron and mathematician Lady Byron. All of Byron's other children were born out of wedlock to other women. Byron separated from his wife a month after Ada was born and left England forever. Four months later, he commemorated the parting in a poem that begins, "Is thy face like thy mother's my fair child! ADA! sole daughter of my house and heart?". He died in Greece when Ada was eight. Her mother remained bitter and promoted Ada's interest in mathemati

# %%
wikipedia.set_lang('fr')
text_fr = wikipedia.page("Lovelace")
print(text_fr.content[:1000])
# Out:
# Ada Lovelace, de son nom complet Augusta Ada King, comtesse de Lovelace, née Ada Byron le 10 décembre 1815 à Londres et morte le 27 novembre 1852 à Marylebone dans la même ville, est une pionnière de la science informatique.
# Elle est principalement connue pour avoir réalisé le premier véritable programme informatique, lors de son travail sur un ancêtre de l'ordinateur : la machine analytique de Charles Babbage. Dans ses notes, on trouve en effet le premier programme publié, destiné à être exécuté par une machine, ce qui fait d'Ada Lovelace « le premier programmeur du monde ». Elle a également entrevu et décrit certaines possibilités offertes par les calculateurs universels, allant bien au-delà du calcul numérique et de ce qu'imaginaient Babbage et ses contemporains,.
# Elle est assez connue dans les pays anglo-saxons et en Allemagne, notamment dans les milieux féministes ; elle est moins connue en France, mais de nombreux développeurs connaissent le langage Ada, nommé en son honneur.

# %% [markdown]
# ## 1- Using NLTK

# %% [markdown]
# --> **For now, we work on the English file**
#
# ### 1.1 Sentence Segmentation
#
# **Exercise 1:** Breaking the text into Sentences
#
# * Import [NLTK](https://www.nltk.org/api/nltk.html)
# * In NLTK, you can use help(X) to get information about function X works e.g., help(nltk.word_tokenize) to get information about NLTK's word tokenizer.
# Use the [help function](https://www.nltk.org/api/nltk.html?highlight=help#module-nltk.help) to see how nltk.sent_tokenize works
# * Now use the [sent_tokenize()](https://www.nltk.org/api/nltk.tokenize.html?highlight=sent_tokenize#nltk.tokenize.sent_tokenize) function to segment the text into sentences.
# * Apply print() to the output of the tokenizer to view the results
# * How many sentences do we have?
#
# You might need to download additional resources for NLTK, e.g. the package 'punkt':

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk

help(nltk.sent_tokenize)

content_en = text_en.content

sentences = nltk.sent_tokenize(content_en)
for i, s in enumerate( sentences):
  print(i, s )

# %% [markdown]
# ### 1.2 Tokenization
#
# * Tokenizing a text file
#
# * Tokenize the text using NLTK [word_tokenize](https://www.nltk.org/api/nltk.tokenize.html?highlight=word_tokenize)
# * Inspect the results: does it work well?
# * How many tokens do we have?
# * How many words / types / unique tokens do we have? Hint: use numpy.unique(list).

# %%
import numpy as np

# Use NLTK to tokenize the text
tokens = nltk.word_tokenize(content_en)

# Print out the tokens
print(tokens)
print('Count tokens: ', len(tokens))
print('Vocabulary / Types / Unique tokens: ', len(np.unique(tokens)))

# %% [markdown]
# ### 1.3 Pre-processing of French text
#
# --> **Now, we will use the French wikipedia page**
#
# **Exercise 3** Tokenization for French
# * Now, try to perform the same pre-processing on the French document
# * Do you see a problem?
# * Check the language option for NLTK, does it work better?
# * Use the *RegexpTokenizer* to solve the issue.

# %%
content_fr = text_fr.content

sentences = nltk.sent_tokenize(content_fr)
for i, s in enumerate( sentences[:10]):
  print(i, s )

# Use NLTK to tokenize the text
tokens = nltk.word_tokenize(content_fr)

# Print out the tokens
print(tokens)
print('Count tokens: ', len(tokens))
print('Vocabulary / Types / Unique tokens: ', len(np.unique(tokens)))


# output deleted because is very long

# %% [markdown]
# Issues with tokenization:
# - look for tokens that are not properly recognized
#
# Unfortunately, using the option "language='french'" doesn't solve all the issues...
#
# What we can do is to use a regular expression; more specifically the base RegexTokenizer

# %%
# Use NLTK to tokenize the text
tokens = nltk.word_tokenize(content_fr, language='french')

# Print out the tokens
print(tokens)

# %%
from nltk import RegexpTokenizer
tokenizer = RegexpTokenizer(r'''\w'|\w+|[^\w\s]''')
tokens = tokenizer.tokenize(content_fr)

# Print out the tokens
print(tokens)

# %% [markdown]
# **Conclusion on Tokenization**
#
# Tokenization is not as simple at it seems. Even for English, the behaviour of the NLTK tokenizer is probably not what you want for many applications, try e.g. to tokenize "I don't like it".

# %%
# Use NLTK to tokenize the text
tokens = nltk.word_tokenize("I don't like it.")

# Print out the tokens
print(tokens)
# Out:
# ['I', 'do', "n't", 'like', 'it', '.']

# %% [markdown]
# ## 2- Using Spacy
#
# All info about Spacy: https://spacy.io/ ; More info on the pipelines: https://spacy.io/usage/processing-pipelines
#
# Spacy is a more realistic library for NLP than NLTK, with higher performances on the basic processing steps.
#
# Spacy can be used to directly tokenize any text.
# With spacy, we build a pipeline that does everything at once.
# To make it work, you need to load a model specific to the target language, for example 'en' for English (there are also some domain specific models).
#
#
# The model corresponds to a processing 'pipeline':
#   by default, it includes the tokenisation, the lemmatization and the POS tagging
#
# Using spacy:
# - import the spacy module into Python
# - load all the necessary models, e.g. for English

# %%
import spacy 
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Then process a text with the pipeline:

# %%
doc = nlp(content_en)

# %% [markdown]
# ### 2.1 Tokenisation
#
# **Exercise 4:** Tokenize the text in French
# * Find a model for French and tokenize the text in the file. Hint: you will need to download the model first, that can be done in the notebook using: *spacy.cli.download( model_name )*
# * What does contain the *doc* variable? Hint: You can either access Spacy's manual on the internet to find out how to access the information, or look at the built-in help by typing help(doc). https://spacy.io/api/doc
# * Print the individual tokens. Do you see any error?
# * How many tokens do we have?
# * How many words / types / unique tokens do we have (i.e. vocabulary size)?
# * Use Pandas to better visualize the results

# %%
import spacy.cli
spacy.cli.download("fr_core_news_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
import spacy

# Load the model
nlp = spacy.load('fr_core_news_sm')

# Preprocess using spacy's pipeline
doc = nlp(content_fr)

print('Preprocessing done')

# Inspect token
# Our preprocessed document is now present as a list of tokens in our doc variable, and we can access its different annotations by looping through it
all_tokens =  []
for token in doc:
  #print( token.text)
  all_tokens.append(token.text)
print('Count tokens', len(all_tokens))
print('Count types', len(np.unique(all_tokens)))
# Out:
# Preprocessing done
# Count tokens 3209
# Count types 1088

# %%
#ou bien
from collections import Counter
comptage_tokens = Counter((token.text for token in doc)) 
print(f"Count tokens : {sum(comptage_tokens.values())}")
print(f"Count types : {len(comptage_tokens.keys())}")
print(f"Most frequent tokens : {comptage_tokens.most_common(n=10)}")
# Out:
# Count tokens : 3209
# Count types : 1088
# Most frequent tokens : [(',', 198), ('de', 134), ('.', 94), ('Ada', 69), ('=', 66), ('et', 65), ('la', 58), ('à', 55), ('\n', 49), ('en', 47)]

# %% [markdown]
# Issues with tokenisation? (à chercher ?)
# * -il
# * machine[2].
# * linguistique[3].

# %% [markdown]
# #### Getting some help
#
# Hint: You can either access Spacy's manual on the internet to find out how to access the information, or look at the built-in help by typing *help(doc)*.
#
# https://spacy.io/api/doc

# %% [markdown]
# #### Pandas
#
# You can use Pandas to better visualize the results

# %%
# Using pandas for a better visualization 
import pandas as pd

spacy_tokens = [w for w in doc]
pd.DataFrame(spacy_tokens,
             columns=['Word'])
# Out:
#           Word
# 0          Ada
# 1     Lovelace
# 2            ,
# 3           de
# 4          son
# ...        ...
# 3204        de
# 3205        l’
# 3206  histoire
# 3207       des
# 3208  sciences
#
# [3209 rows x 1 columns]

# %%
w0 = spacy_tokens[0]
w0
# Out:
# Ada

# %% [markdown]
# ### 2.2 Sentence segmentation
#
# **Exercise 5:**
# Apart from token segmentation, Spacy has also automatically segmented our document intro sentences.
# * **(a)** Print out the different sentences of the document.
# Hint: Look at the "Data descriptors " in the help page for 'doc'.

# %%
# Print the sentences
for i, sent in enumerate( doc.sents ):
  print( i, sent.text.strip() )

# %% [markdown]
# ## 3- Further pre-processing
#
# We saw earlier that the most frequent words are punctuation and function words.
# In order to find the most important words, e.g. to index documents, we probably want to remove these tokens.
# We are thus now going to **remove punctuation signs and "stop words"**.
# Note that for a full normalization, we would probably also lower case the first word of each sentence, and all words that are not tagged as proper nouns (but it requires pos tagging).
#
# Exercise 6:
# * Define a function that segments, tokenizes, removes punctuation and removes stop words. **Hint** spacy.lang contains language specific data for each language, in particular stop words lists.
# * Apply this function to the french wikipedia page
# * Display a panda dataframe containing an ordered list of the tokens after cleaning and their frequency

# %%
# on a vu plus mot que les mots les plus courants sont des ponctuations et mots fonctionnels. si on veut garder les mots importants par exemple pour indexer le texte
# on va enlever les tokens de ponctuation et les "stop words"
# pour normaliser complètement il faudrait passer en minuscule le premier mot de chaque phrase, si ce n'est pas un nom propre (mais on verra ça plus loin)
import string
punct = set(string.punctuation+"«»")
print("Punctuation signs: ", punct)

from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop

print("Stop words for French:", fr_stop)

def cleanup(text):
  text = text.lower().replace("\n","")# en premiere approximation
  doc = nlp(text)
  sents = doc.sents
  tokens = []
  for s in sents:
    tokens.extend([t.text for t in s if t.text not in (fr_stop|punct)])
  return list(tokens)
    
cleaned = cleanup(content_fr)
print("Cleaned, # tokens:", len(cleaned))
# Out:
# Punctuation signs:  {'|', '[', '$', '?', '=', '\\', '»', '`', '^', '/', '"', '~', '#', '&', '_', '!', '(', ';', '<', '+', ')', '.', '{', '>', '}', ']', '«', '@', ':', '*', '%', "'", '-', ','}
# Stop words for French: {'stop', 'abord', 'quelques', 'nôtre', 'egalement', 'revoila', 'possible', 'revoici', 'suivante', 'antérieure', 'avec', 'onzième', 'néanmoins', 'telle', 'ouste', 'ça', 'doivent', 'mille', 'ta', 'vôtres', 'dixième', 'as', 'moi-meme', "d'", 'c’', 'dès', 'dans', 'leur', 'comme', 'mien', 'que', 'pu', 'da', 'suivre', 'me', 'au', 'dits', 'quel', 'restent', 'toujours', 'lui-meme', 'dessus', "quelqu'un", 'également', 'vingt', 'surtout', 'peut', 'gens', 'cela', 'soi', 'facon', 'sans', 'peu', 'soit', 'en', 'meme', 'enfin', 'mais', 'quelque', 'car', 'très', 'celles-la', 'lorsque', 'malgré', 'de', 'exactement', 'apres', 'nul', 'quatorze', 'outre', 'quoique', 'du', 'celle-là', 'avoir', 'bat', 'duquel', 'lesquelles', 'faisaient', "j'", 'sept', 'hormis', 'celle-ci', 'assez', 'puis', 'nôtres', 'restant', 'toi-meme', 'dix-sept', 'telles', 'differente', 'celui-là', 'allons', 'ils', 'onze', 'aie', 'vôtre', 'relativement', 'm’', 'où', 'suffisante', 'qui', 'plus', 'malgre', 'tente', 'ce', 'pourrais', 'sienne', 'alors', 'auraient', 'neanmoins', 'hem', 'nombreuses', 'septième', 'unes', 'lui-même', 'trois', 'même', 'chaque', 'sont', 'autre', 'retour', 'dire', 'précisement', 'spécifique', 'pouvait', 'pendant', 'basee', 'i', 'seul', 'toi-même', 'reste', 'suffisant', 'quant-à-soi', 'dite', 'tout', 'chez', 'parler', 'vous', 'celui-la', 'ha', 'une', 'là', 'suffit', "s'", 'dix-huit', 'auxquels', 'maintenant', 'celui-ci', 'tenant', 'pas', 'ceux', 'soixante', 'après', 'o', 'elles-memes', 'entre', 'ma', 'prealable', 'seuls', 'vers', 'debout', 'anterieur', 'diverse', 'auxquelles', 'et', 'lès', 'tel', 'se', 'seize', "c'", 'hors', 'envers', 'combien', 'desquelles', 'vont', 'etre', 'auront', 'l’', 'voici', 'notamment', 'fais', 'uns', 'hi', 'personne', 'houp', 'ouverts', 'cette', "l'", 'sinon', 'or', 'avons', 'tend', 'anterieures', 'deja', 'comment', 'elles-mêmes', 'procedant', 'rend', 'avait', 'il', 'puisque', 'vos', 'dessous', 'troisièmement', 'té', 'tant', 'est', 'sera', 'na', 'plutôt', 'chacun', 'dix-neuf', 'certain', 'devra', 'être', 'si', 'ait', 'different', 'quatrième', 'ceux-là', 'merci', 'parmi', 'lors', 'diverses', 'memes', "m'", 'on', 'qu’', 'nouveau', 'premièrement', 'vu', 'suit', 'ces', 'cinq', 'antérieur', 'certes', 'différents', 'vous-mêmes', 'sait', 'mes', 'près', 'importe', 'mêmes', 'afin', 'autrui', 'quinze', 'mienne', 'à', 'es', 'sien', 'spécifiques', 'avaient', 'dix', 'antérieures', 'moi', 'ceci', 'j’', 'auquel', 'revoilà', 'tes', 'dehors', 'préalable', 'quatre-vingt', 'elle-même', 'deuxièmement', 'longtemps', 'par', 'plusieurs', 'voilà', 'fait', 'vas', 'precisement', "qu'", 'celle', 'plutot', 'vé', 'cent', 'différente', 'a', 'derrière', 'certains', 'juste', 'lui', 'doit', 'son', 'dedans', 'douzième', 'encore', 'première', 'nous-mêmes', 'tien', 'ton', 'divers', 'depuis', 'quarante', 'siens', 'durant', 'seule', 'douze', 'suivantes', 'tellement', 'semble', 'pres', 'différentes', 'le', 'toute', 'sa', 'ni', 'parlent', 'ayant', 'seront', 'differentes', 'déjà', 'premier', 'quiconque', 'sixième', 'moi-même', 'lequel', 'sur', 'tenir', 'différent', 'eux', 'y', "n'", 'touchant', 'etc', 'parfois', 'quatrièmement', 'ainsi', 'autres', 'neuvième', 'hou', 'ouias', 'certaines', 'pour', 'certaine', 'possibles', 'six', 'hep', 'votre', 'parle', 'delà', 'suivants', 'nous', 'eu', 'cinquantième', 'pense', 'un', 'voila', 'differents', 'moindres', 'vais', 'aurait', 'ès', 'miens', 'nos', 'permet', 'etaient', 'quand', 'souvent', 'faisant', 'specifique', 'relative', 'autrement', 'siennes', 'tiennes', 'semblable', 'aux', 'moins', 'tous', 'hé', 'celui', 'specifiques', 'n’', 'mon', 'parce', 'cinquante', 's’', 'dit', 'selon', 'était', 'ouvert', 'seules', 'ô', 'façon', 'ont', 'cinquantaine', 'dont', 'te', 'treize', 'feront', 'huitième', 'huit', 'deuxième', 'font', 'concernant', 'ci', 'celles-là', 'allaient', 'pourrait', 'seulement', 'lesquels', 'déja', 'quoi', 'directe', 'désormais', 'donc', 'avais', 'maint', 'ceux-ci', 't’', 'elles', 'tres', 'serait',  ...
# Cleaned, # tokens: 1431
# ['ada', 'lovelace', 'nom', 'complet', 'augusta', 'ada', 'king', 'comtesse', 'lovelace', 'née', 'ada', 'byron', '10', 'décembre', '1815', 'londres', 'morte', '27', 'novembre', '1852', 'marylebone', 'ville', 'pionnière', 'science', 'informatique.elle', 'principalement', 'connue', 'réalisé', 'véritable', 'programme', 'informatique', 'travail', 'ancêtre', 'ordinateur', 'machine', 'analytique', 'charles', 'babbage', 'notes', 'trouve', 'programme', 'publié', 'destiné', 'exécuté', 'machine', 'ada', 'lovelace', 'programmeur', 'monde', 'entrevu', 'décrit', 'possibilités', 'offertes', 'calculateurs', 'universels', 'allant', 'bien', 'au-delà', 'calcul', 'numérique', 'imaginaient', 'babbage', 'contemporains,.elle', 'connue', 'pays', 'anglo-saxons', 'allemagne', 'milieux', 'féministes', 'connue', 'france', 'développeurs', 'connaissent', 'langage', 'ada', 'nommé', 'honneur', 'biographie', 'environnement', 'familial', 'ada', 'fille', 'légitime', 'poète', 'george', 'gordon', 'byron', 'épouse', 'annabella', 'milbanke', 'femme', 'intelligente', 'cultivée', 'cousine', 'caroline', 'lamb', 'liaison', 'byron', 'fut', 'origine', 'scandale', 'prénom', 'ada', 'augusta', 'été', 'choisi', 'hommage', 'augusta', 'leigh', 'demi-sœur', 'byron', 'dernier', 'relations', 'incestueuses', 'prénom', 'ada', 'été', 'choisi', 'byron', 'court', 'ancien', 'vocalique', 'augusta', 'encouragea', 'byron', 'marier', 'éviter', 'scandale', 'épousa', 'annabella', 'contrecœur[réf', 'souhaitée', 'janvier', '1815', 'ada', 'naît', 'décembre', 'année', 'suite', 'tentatives', 'viol', 'état', 'ivresse', 'part', 'byron', 'annabella', 'quitte', 'byron', '16', 'janvier', '1816', 'gardant', 'ada', '21', 'avril', 'byron', 'signe', 'acte', 'séparation', 'quitte', 'royaume', 'uni', 'revit', 'jamais.annabella', 'adorait', 'mathématiques', 'byron', 'appelait', 'princesse', 'parallélogrammes', 'annabella', 'fit', 'sorte', 'tuteurs', 'ada', 'donnent', 'éducation', 'approfondie', 'mathématiques', 'sciences', 'inhabituel', 'époque', 'éducation', 'jeune', 'fille', 'noblesse', '1832', 'ada', 'rencontre', 'mary', 'somerville', 'éminente', 'chercheuse', 'autrice', 'scientifique', 'xixe', 'siècle', 'encourage', 'aide', 'progresser', 'mathématiques', '5', 'juin', '1833', 'mary', 'présente', 'charles', 'babbage', 'ada', '—', 'âgée', '17', 'ans', '—', 'immédiatement', 'fascinée', 'machines', 'calcul', 'deviennent', 'proches', 'ada', 'semblant', 'trouver', 'babbage', 'père', 'jamais', 'connaissances', 'compte', 'david', 'brewster', 'charles', 'wheatstone', 'charles', 'dickens', 'michael', 'faraday.elle', 'marie', '1835', 'william', 'king', '1er', 'comte', 'lovelace', 'enfants', 'byron', 'né', '12', 'mai', '1836', 'annabella', 'anne', 'blunt', 'née', '22', 'septembre', '1837', 'ralph', 'gordon', 'né', '2', 'juillet', '1839', 'william', 'dévoué', 'ada', 'encourageait', 'goûts', 'activités', 'ada', 'mathématiques', 'famille', 'vécut', 'ockham', 'park', 'okham', 'titre', 'nom', 'complet', 'furent', 'grande', 'partie', 'vie', 'honorable', 'augusta', 'ada', 'comtesse', 'lovelace', 'connue', 'nom', 'ada', 'lovelace', 'lady', 'lovelace.la', 'santé', 'fragile', 'ada', 'mise', 'épreuve', 'grossesses', 'responsabilités', 'mère', 'maîtresse', 'maison', 'tiennent', 'écartée', 'activités', 'mathématiques', "jusqu'", '1839', 'date', 'éprouve', 'besoin', 'reprendre', 'étude', 'mathématiques', 'demande', 'babbage', 'recommander', 'tuteur', 'célèbre', 'mathématicien', 'auguste', 'morgan', 'accepte', 'charge', 'études', 'ada', 'reprennent', 'morgan', 'trouve', 'ada', 'élève', 'enthousiaste', 'créative', 'ada', 'prend', 'confiance', 'capacités', 'mathématiques', 'encouragée', 'retours', 'positifs', 'morgan', '6', 'février', '1841', 'ada', 'écrit', 'mère', 'lettre', 'goûts', 'aspirations', 'crois', 'possède', 'singulière', 'combinaison', 'qualités', 'précisément', 'ajustées', 'prédisposer', 'devenir', 'exploratrice', 'réalités', 'cachées', 'nature', 'mentionne', 'énergie', 'inépuisable', 'insatiable', 'trouvé', 'sens', 'vie. ...

# %%
print(cleaned[:100])
# Out:
# ['ada', 'lovelace', 'nom', 'complet', 'augusta', 'ada', 'king', 'comtesse', 'lovelace', 'née', 'ada', 'byron', '10', 'décembre', '1815', 'londres', 'morte', '27', 'novembre', '1852', 'marylebone', 'ville', 'pionnière', 'science', 'informatique.elle', 'principalement', 'connue', 'réalisé', 'véritable', 'programme', 'informatique', 'travail', 'ancêtre', 'ordinateur', 'machine', 'analytique', 'charles', 'babbage', 'notes', 'trouve', 'programme', 'publié', 'destiné', 'exécuté', 'machine', 'ada', 'lovelace', 'programmeur', 'monde', 'entrevu', 'décrit', 'possibilités', 'offertes', 'calculateurs', 'universels', 'allant', 'bien', 'au-delà', 'calcul', 'numérique', 'imaginaient', 'babbage', 'contemporains,.elle', 'connue', 'pays', 'anglo-saxons', 'allemagne', 'milieux', 'féministes', 'connue', 'france', 'développeurs', 'connaissent', 'langage', 'ada', 'nommé', 'honneur', 'biographie', 'environnement', 'familial', 'ada', 'fille', 'légitime', 'poète', 'george', 'gordon', 'byron', 'épouse', 'annabella', 'milbanke', 'femme', 'intelligente', 'cultivée', 'cousine', 'caroline', 'lamb', 'liaison', 'byron', 'fut', 'origine']

# %%
import pandas as pds
table = pds.Series(cleaned)
cts = table.value_counts()
cts.sort_values(inplace=True,ascending=False)
cts.head(20)
# Out:
# ada              65
# babbage          27
# lovelace         24
# machine          22
# byron            15
# the              15
# mathématiques    12
# notes            11
# informatique     10
# programme         9
# of                9
# nom               9
# charles           9
# calcul            7
# 2                 7
# fille             7
# été               6
# portail           6
# analytique        6
# augusta           6
# dtype: int64

# %%
type(fr_stop)
# Out:
# set

# %% [markdown]
# ## 4- POS tagging
#
# Remember that the model corresponds to a processing 'pipeline' in Spacy:
#   - by default, it includes the tokenisation, the lemmatization and the POS tagging
#
# **Exercise 7**
# - print each individual token, together with its lemmatized form and part of speech tag
# - Use Panda to better visualize the results
# - Look at the results, do you see any error?
# - You can use the method 'spacy.explain' to have information about some annotation, for example the POS tags. Apply it to each POS tag to get a more detailed label.

# %%
import spacy

# Load the model
nlp = spacy.load('fr_core_news_sm')


# Preprocess using spacy's pipeline
doc = nlp(content_fr)

# Inspect tokens, lemmas, and pos tags
for token in doc:
  print( token.text, token.lemma_, token.pos_)
# Out:
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# , , PUNCT
# de de ADP
# son son DET
# nom nom NOUN
# complet complet ADJ
# Augusta Augusta PROPN
# Ada Ada PROPN
# King King PROPN
# , , PUNCT
# comtesse comtesse NOUN
# de de ADP
# Lovelace Lovelace PROPN
# , , PUNCT
# née naître VERB
# Ada Ada X
# Byron Byron PROPN
# le le DET
# 10 10 NUM
# décembre décembre NOUN
# 1815 1815 NUM
# à à ADP
# Londres Londres PROPN
# et et CCONJ
# morte morte ADV
# le le DET
# 27 27 NUM
# novembre novembre NOUN
# 1852 1852 NUM
# à à ADP
# Marylebone Marylebone PROPN
# dans dans ADP
# la le DET
# même même ADJ
# ville ville NOUN
# , , PUNCT
# est être AUX
# une un DET
# pionnière pionnier NOUN
# de de ADP
# la le DET
# science science NOUN
# informatique informatique ADJ
# . . PUNCT
#
#
#  SPACE
# Elle lui PRON
# est être AUX
# principalement principalement ADV
# connue connaître VERB
# pour pour ADP
# avoir avoir AUX
# réalisé réaliser VERB
# le le DET
# premier premier ADJ
# véritable véritable ADJ
# programme programme NOUN
# informatique informatique ADJ
# , , PUNCT
# lors lors ADV
# de de ADP
# son son DET
# travail travail NOUN
# sur sur ADP
# un un DET
# ancêtre ancêtre NOUN
# de de ADP
# l' le DET
# ordinateur ordinateur NOUN
# : : PUNCT
# la le DET
# machine machine NOUN
# analytique analytique ADJ
# de de ADP
# Charles Charles PROPN
# Babbage Babbage PROPN
# . . PUNCT
# Dans dans ADP
# ses son DET
# notes note NOUN
# , , PUNCT
# on on PRON
# trouve trouve VERB
# en en ADP
# effet effet NOUN
# le le DET
# premier premier ADJ
# programme programme NOUN
# publié publier VERB
# , , PUNCT
# destiné destiner VERB
# à à ADP
# être être AUX
# exécuté exécuter VERB
# par par ADP
# une un DET
# machine machine NOUN
# , , PUNCT
# ce ce PRON
# qui qui PRON
# fait faire VERB
# d' de ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# « « PROPN
# le le DET
# premier premier ADJ
# programmeur programmeur NOUN
# du de ADP
# monde monde NOUN
# » » PUNCT
# . . PUNCT
# Elle lui PRON
# a avoir AUX
# également également ADV
# entrevu entrevoir VERB
# et et CCONJ
# décrit décrire VERB
# certaines certain DET
# possibilités possibilité NOUN
# offertes offrir ADJ
# par par ADP
# les le DET
# calculateurs calculateur NOUN
# universels universel ADJ
# , , PUNCT
# allant aller VERB
# bien bien ADV
# au-delà au-delà ADV
# du de ADP
# calcul calcul NOUN
# numérique numérique ADJ
# et et CCONJ
# de de ADP
# ce ce PRON
# qu' qu' PRON
# imaginaient imaginaient NOUN
# Babbage Babbage PROPN
# et et CCONJ
# ses son DET
# contemporains contemporain NOUN
# , , PUNCT
# . . PUNCT
#
#
#  SPACE
# Elle lui PRON
# est être AUX
# assez assez ADV
# connue connaître VERB
# dans dans ADP
# les le DET
# pays pays NOUN
# anglo-saxons anglo-saxon NOUN
# et et CCONJ
# en en ADP
# Allemagne Allemagne PROPN
# , , PUNCT
# notamment notamment ADV
# dans dans ADP
# les le DET
# milieux milieu NOUN
# féministes féministe ADJ
# ; ; PUNCT
# elle lui PRON
# est être AUX
# moins moins ADV
# connue connaître VERB
# en en ADP
# France France PROPN
# , , PUNCT
# mais mais CCONJ
# de de DET
# nombreux nombreux ADJ
# développeurs développeur NOUN
# connaissent connaître VERB
# le le DET
# langage langage NOUN
# Ada Ada PROPN
# , , PUNCT
# nommé nommer VERB
# en en ADP
# son son DET
# honneur honneur NOUN
# . . PUNCT
#
#
#
#
#
#
#  SPACE
# = = NOUN
# = = X
# Biographie Biographie PROPN
# = = AUX
# = = X
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = X
# = = PRON
# Environnement environnement NOUN
# familial familial ADJ
# = = AUX
# = = X
# = = VERB
#
#
#
#
#  SPACE
# Ada Ada PROPN
# était être AUX
# la le DET
# seule seul ADJ
# fille fille NOUN
# légitime légitime ADJ
# du de ADP
# poète poète ADJ
# George George PROPN
# Gordon Gordon X
# Byron Byron PROPN
# et et CCONJ
# de de ADP
# son son DET
# épouse épouse NOUN
# Annabella Annabella PROPN
# Milbanke Milbanke PROPN
# , , PUNCT
# une un DET
# femme femme NOUN
# intelligente intelligent ADJ
# et et CCONJ
# cultivée cultiver VERB
# , , PUNCT
# cousine cousin NOUN
# de de ADP
# Caroline caroline NOUN
# Lamb Lamb PROPN
# , , PUNCT
# dont dont PRON
# la le DET
# liaison liaison NOUN
# avec avec ADP
# Byron Byron PROPN
# fut être AUX
# à à ADP
# l' le DET
# origine origine NOUN
# d' de ADP
# un un DET
# scandale scandale NOUN
# . . PUNCT
# Le le DET
# premier premier ADJ
# prénom prénom NOUN
# d' de ADP
# Ada Ada PROPN
# , , PUNCT
# Augusta Augusta PROPN
# , , PUNCT
# aurait avoir AUX
# été être AUX
# choisi choisir VERB
# en en ADP
# hommage hommage NOUN
# à à ADP
# Augusta Augusta PROPN
# Leigh Leigh PROPN
# , , PUNCT
# la le DET
# demi-sœur demi-sœur NOUN
# de de ADP
# Byron Byron PROPN
# , , PUNCT
# avec avec ADP
# qui qui PRON
# ce ce DET
# dernier dernier ADJ
# aurait avoir AUX
# eu avoir VERB
# des un DET
# relations relation NOUN
# incestueuses incestueux ADJ
# . . PUNCT
# Le le DET
# prénom prénom NOUN
# Ada Ada PROPN
# aurait avoir AUX
# été être AUX
# choisi choisir VERB
# par par ADP
# Byron Byron PROPN
# lui-même lui-même PRON
# , , PUNCT
# car car CCONJ
# il il PRON
# était être AUX
# « « VERB
# court court ADJ
# , , PUNCT
# ancien ancien ADJ
# et et CCONJ
# vocalique vocalique ADJ
# » » PUNCT
# . . PUNCT
# C' ce PRON
# est être AUX
# Augusta Augusta PROPN
# qui qui PRON
# encouragea encourager VERB
# Byron Byron PROPN
# à à ADP
# se se PRON
# marier marier PROPN
# pour pour ADP
# éviter éviter VERB
# un un DET
# scandale scandale NOUN
# , , PUNCT
# et et CCONJ
# il il PRON
# épousa épouser VERB
# Annabella annabeller VERB
# à à ADP
# contrecœur[réf contrecœur[réf NOUN
# . . PUNCT
# souhaitée souhaitée NOUN
# ] ] PUNCT
# , , PUNCT
# en en ADP
# janvier janvier NOUN
# 1815 1815 NUM
# . . PUNCT
# Ada ader VERB
# naît naître VERB
# en en ADP
# décembre décembre NOUN
# de de ADP
# cette ce DET
# même même ADJ
# année année NOUN
# . . PUNCT
# À à ADP
# la le DET
# suite suite NOUN
# de de ADP
# quatre quatre NUM
# tentatives tentative NOUN
# de de ADP
# viol viol NOUN
# en en ADP
# état état NOUN
# d' de ADP
# ivresse ivresse NOUN
# de de ADP
# la le DET
# part part NOUN
# de de ADP
# Byron Byron PROPN
# , , PUNCT
# Annabella Annabella PROPN
# quitte quitte ADJ
# Byron Byron PROPN
# le le DET
# 16 16 NUM
# janvier janvier NOUN
# 1816 1816 NUM
# , , PUNCT
# gardant garder VERB
# Ada ada PRON
# avec avec ADP
# elle lui PRON
# . . PUNCT
# Le le DET
# 21 21 NUM
# avril avril NOUN
# , , PUNCT
# Byron Byron PROPN
# signe signe VERB
# l' le DET
# acte acte NOUN
# de de ADP
# séparation séparation NOUN
# , , PUNCT
# puis puis CCONJ
# quitte quitte VERB
# le le DET
# Royaume Royaume PROPN
# - - PROPN
# Uni Uni PROPN
# pour pour ADP
# toujours toujours ADV
# . . PUNCT
# Il il PRON
# ne ne ADV
# les le DET
# revit revit NOUN
# jamais jamais ADV
# . . PUNCT
#
#
#  SPACE
# Annabella annabella NOUN
# adorait adorer VERB
# les le DET
# mathématiques mathématique NOUN
# . . PUNCT
# Byron Byron PROPN
# l’ l’ SPACE
# appelait appeler VERB
# même même ADV
# parfois parfois ADV
# « « ADJ
# la le DET
# princesse princesse NOUN
# des de ADP
# parallélogrammes parallélogramme NOUN
# » » PUNCT
# . . PUNCT
# Annabella annabella NOUN
# fit faire VERB
# en en ADP
# sorte sorte NOUN
# que que SCONJ
# les le DET
# tuteurs tuteur NOUN
# d' de ADP
# Ada Ada PROPN
# lui lui PRON
# donnent donner VERB
# une un DET
# éducation éducation NOUN
# approfondie approfondir VERB
# en en ADP
# mathématiques mathématique NOUN
# et et CCONJ
# en en ADP
# sciences science NOUN
# , , PUNCT
# ce ce PRON
# qui qui PRON
# était être AUX
# tout tout ADV
# à à ADP
# fait fait NOUN
# inhabituel inhabituel NOUN
# à à ADP
# l' le DET
# époque époque NOUN
# dans dans ADP
# l' le DET
# éducation éducation NOUN
# d' de ADP
# une un DET
# jeune jeune ADJ
# fille fille NOUN
# de de ADP
# la le DET
# noblesse noblesse NOUN
# . . PUNCT
# En en ADP
# 1832 1832 NUM
# , , PUNCT
# Ada Ada PROPN
# rencontre rencontre X
# Mary Mary PROPN
# Somerville Somerville PROPN
# , , PUNCT
# éminente éminent ADJ
# chercheuse chercheur ADJ
# et et CCONJ
# autrice autrice NOUN
# scientifique scientifique ADJ
# du de ADP
# XIXe xix ADJ
# siècle siècle NOUN
# , , PUNCT
# qui qui PRON
# l' le DET
# encourage encourage NOUN
# et et CCONJ
# l' le DET
# aide aide NOUN
# à à ADP
# progresser progresser VERB
# en en ADP
# mathématiques mathématique NOUN
# . . PUNCT
# Le le DET
# 5 5 NUM
# juin juin NOUN
# 1833 1833 NUM
# , , PUNCT
# Mary Mary PROPN
# lui lui PRON
# présente présente VERB
# Charles Charles PROPN
# Babbage Babbage PROPN
# , , PUNCT
# et et CCONJ
# Ada Ada PROPN
# — — ADJ
# alors alors ADV
# âgée âgé ADJ
# de de ADP
# 17 17 NUM
# ans an NOUN
# — — VERB
# est être AUX
# immédiatement immédiatement ADV
# fascinée fasciner VERB
# par par ADP
# ses son DET
# machines machine NOUN
# à à ADP
# calcul calcul NOUN
# . . PUNCT
# Ils il PRON
# deviennent devenir VERB
# très très ADV
# proches proche ADJ
# , , PUNCT
# Ada Ada PROPN
# semblant sembler VERB
# trouver trouver VERB
# en en ADP
# Babbage babbage NOUN
# le le DET
# père père NOUN
# qu' que SCONJ
# elle lui PRON
# n' n' ADV
# avait avoir AUX
# jamais jamais ADV
# eu avoir VERB
# . . PUNCT
# Parmi parmi ADP
# ses son DET
# autres autre ADJ
# connaissances connaissance NOUN
# , , PUNCT
# on on PRON
# compte compte VERB
# David David PROPN
# Brewster Brewster PROPN
# , , PUNCT
# Charles Charles PROPN
# Wheatstone Wheatstone PROPN
# , , PUNCT
# Charles Charles PROPN
# Dickens Dickens PROPN
# et et CCONJ
# Michael Michael PROPN
# Faraday Faraday PROPN
# . . PUNCT
#
#
#  SPACE
# Elle lui PRON
# se se PRON
# marie marier VERB
# en en ADP
# 1835 1835 NUM
# avec avec ADP
# William William PROPN
# King King PROPN
# , , PUNCT
# 1er premier ADJ
# comte comte NOUN
# de de ADP
# Lovelace Lovelace PROPN
# . . PUNCT
# Ils il PRON
# auront avoir VERB
# trois trois NUM
# enfants enfant NOUN
# : : PUNCT
# Byron Byron PROPN
# , , PUNCT
# né naître VERB
# le le DET
# 12 12 NUM
# mai mai NOUN
# 1836 1836 NUM
# , , PUNCT
# Annabella Annabella PROPN
# ( ( PUNCT
# Anne anne NOUN
# Blunt Blunt PROPN
# ) ) PUNCT
# née naître VERB
# le le DET
# 22 22 NUM
# septembre septembre NOUN
# 1837 1837 NUM
# et et CCONJ
# Ralph Ralph PROPN
# Gordon gordon NOUN
# né naître VERB
# le le DET
# 2 2 NUM
# juillet juillet NOUN
# 1839 1839 NUM
# . . PUNCT
# William william NOUN
# était être AUX
# dévoué dévoué ADJ
# à à ADP
# Ada Ada PROPN
# et et CCONJ
# encourageait encourager VERB
# les le DET
# goûts goût NOUN
# et et CCONJ
# les le DET
# activités activité NOUN
# d' de ADP
# Ada Ada PROPN
# en en ADP
# mathématiques mathématique NOUN
# . . PUNCT
# La le DET
# famille famille NOUN
# vécut vivre VERB
# à à ADP
# Ockham Ockham PROPN
# Park Park PROPN
# , , PUNCT
# à à ADP
# Okham Okham PROPN
# ( ( PUNCT
# en en NOUN
# ) ) PUNCT
# . . PUNCT
# Son son DET
# titre titre NOUN
# et et CCONJ
# son son DET
# nom nom NOUN
# complet complet ADJ
# furent être AUX
# pendant pendant ADP
# la le DET
# plus plus ADV
# grande grand ADJ
# partie partie NOUN
# de de ADP
# sa son DET
# vie vie NOUN
# La le DET
# très très ADV
# honorable honorable ADJ
# Augusta Augusta PROPN
# Ada Ada PROPN
# , , PUNCT
# comtesse comtesse NOUN
# de de ADP
# Lovelace Lovelace PROPN
# . . PUNCT
# Elle lui PRON
# est être AUX
# plus plus ADV
# connue connaître VERB
# sous sous ADP
# le le DET
# nom nom NOUN
# de de ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# ou ou CCONJ
# Lady Lady PROPN
# Lovelace Lovelace PROPN
# . . PUNCT
#
#
#
#
#  SPACE
# La le DET
# santé santé NOUN
# fragile fragile ADJ
# d' de ADP
# Ada Ada PROPN
# , , PUNCT
# mise mettre VERB
# à à ADP
# l' le DET
# épreuve épreuve NOUN
# par par ADP
# les le DET
# grossesses grossesse NOUN
# , , PUNCT
# ainsi ainsi ADV
# que que SCONJ
# ses son DET
# responsabilités responsabilité NOUN
# de de ADP
# mère mère NOUN
# et et CCONJ
# de de ADP
# maîtresse maîtresse NOUN
# de de ADP
# maison maison NOUN
# , , PUNCT
# la le DET
# tiennent tiennent NOUN
# écartée écarter VERB
# de de ADP
# ses son DET
# activités activité NOUN
# mathématiques mathématique ADJ
# jusqu' jusque ADP
# en en ADP
# 1839 1839 NUM
# . . PUNCT
# À à ADP
# cette ce DET
# date date NOUN
# , , PUNCT
# elle lui PRON
# éprouve éprouve VERB
# le le DET
# besoin besoin NOUN
# de de ADP
# reprendre reprendre VERB
# l' le DET
# étude étude NOUN
# des de ADP
# mathématiques mathématique NOUN
# et et CCONJ
# demande demande VERB
# à à ADP
# Babbage babbage NOUN
# de de ADP
# lui lui PRON
# recommander recommander VERB
# un un DET
# tuteur tuteur NOUN
# : : PUNCT
# le le DET
# célèbre célèbre NOUN
# mathématicien mathématicien ADV
# Auguste Auguste PROPN
# De de ADP
# Morgan morgan NOUN
# accepte accepte VERB
# cette ce DET
# charge charge NOUN
# . . PUNCT
# Les le DET
# études étude NOUN
# d' de ADP
# Ada Ada PROPN
# reprennent reprennent ADV
# , , PUNCT
# et et CCONJ
# De de ADP
# Morgan morgan NOUN
# trouve trouve VERB
# en en ADP
# Ada ada NOUN
# une un DET
# élève élève NOUN
# enthousiaste enthousiaste ADJ
# et et CCONJ
# créative créatif ADJ
# . . PUNCT
# Ada ader VERB
# prend prendre VERB
# confiance confiance NOUN
# dans dans ADP
# ses son DET
# capacités capacité NOUN
# en en ADP
# mathématiques mathématique NOUN
# , , PUNCT
# encouragée encourager VERB
# par par ADP
# les le DET
# retours retour NOUN
# positifs positif ADJ
# de de ADP
# De de ADP
# Morgan Morgan PROPN
# . . PUNCT
# Le le DET
# 6 6 NUM
# février février NOUN
# 1841 1841 NUM
# , , PUNCT
# Ada Ada PROPN
# écrit écrire VERB
# à à ADP
# sa son DET
# mère mère NOUN
# une un DET
# lettre lettre NOUN
# où où PRON
# elle lui PRON
# parle parle VERB
# de de ADP
# ses son DET
# goûts goût NOUN
# et et CCONJ
# aspirations aspiration NOUN
# : : PUNCT
# « « PROPN
# Je je PRON
# crois croire VERB
# que que SCONJ
# je je PRON
# possède posséder VERB
# une un DET
# singulière singulière NOUN
# combinaison combinaison ADJ
# de de ADP
# qualités qualité NOUN
# , , PUNCT
# qui qui PRON
# semble semble VERB
# précisément précisément ADV
# ajustées ajuster VERB
# pour pour ADP
# me me PRON
# prédisposer prédisposer VERB
# à à ADP
# devenir devenir VERB
# une un DET
# exploratrice exploratrice NOUN
# des de ADP
# réalités réalité NOUN
# cachées cacher VERB
# de de ADP
# la le DET
# Nature nature NOUN
# » » PUNCT
# . . PUNCT
# Elle lui PRON
# mentionne mentionn ADJ
# son son DET
# « « NOUN
# énergie énergie NOUN
# inépuisable inépuisable ADJ
# et et CCONJ
# insatiable insatiable ADJ
# » » ADJ
# et et CCONJ
# pense pense NOUN
# avoir avoir AUX
# trouvé trouver VERB
# un un DET
# sens sens NOUN
# à à ADP
# sa son DET
# vie vie NOUN
# . . PUNCT
#
#
#  SPACE
# En en ADP
# 1841 1841 NUM
# , , PUNCT
# Ada Ada PROPN
# a avoir AUX
# de de ADP
# nouveau nouveau ADJ
# des un DET
# problèmes problème NOUN
# de de ADP
# santé santé NOUN
# , , PUNCT
# mais mais CCONJ
# elle lui PRON
# revient revenir VERB
# aux à ADP
# mathématiques mathématique NOUN
# fin fin NOUN
# 1842 1842 NUM
# . . PUNCT
# Elle lui PRON
# tourne tourne VERB
# dès dès ADP
# lors lors ADV
# entièrement entièrement ADV
# son son DET
# travail travail NOUN
# vers vers ADP
# la le DET
# machine machine NOUN
# analytique analytique ADJ
# de de ADP
# Babbage Babbage PROPN
# , , PUNCT
# et et CCONJ
# propose propose VERB
# à à ADP
# ce ce DET
# dernier dernier ADJ
# ses son DET
# services service NOUN
# pour pour ADP
# en en ADP
# poursuivre poursuivre VERB
# le le DET
# développement développement NOUN
# et et CCONJ
# la le DET
# promotion promotion NOUN
# . . PUNCT
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = X
# = = PRON
# Mémoire mémoire NOUN
# sur sur ADP
# la le DET
# machine machine NOUN
# de de ADP
# Babbage Babbage PROPN
# = = AUX
# = = X
# = = VERB
#
#
#
#
#  SPACE
# En en ADP
# octobre octobre NOUN
# 1842 1842 NUM
# , , PUNCT
# paraît paraître VERB
# en en ADP
# français français NOUN
# , , PUNCT
# dans dans ADP
# un un DET
# journal journal NOUN
# suisse suisse ADJ
# , , PUNCT
# une un DET
# description description NOUN
# de de ADP
# la le DET
# machine machine NOUN
# analytique analytique ADJ
# de de ADP
# Babbage Babbage PROPN
# réalisée réaliser VERB
# par par ADP
# le le DET
# mathématicien mathématicien NOUN
# italien italien ADJ
# Louis-Frédéric Louis-Frédéric PROPN
# Ménabréa Ménabréa PROPN
# ( ( PUNCT
# 1809 1809 NOUN
# - - NOUN
# 1896 1896 NOUN
# ) ) PUNCT
# . . PUNCT
# Charles Charles PROPN
# Wheatstone Wheatstone PROPN
# propose propose VERB
# à à ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# , , PUNCT
# qui qui PRON
# a avoir VERB
# un un DET
# bon bon ADJ
# niveau niveau NOUN
# de de ADP
# français français NOUN
# , , PUNCT
# de de ADP
# traduire traduire VERB
# ce ce DET
# mémoire mémoire NOUN
# pour pour ADP
# le le DET
# journal journal NOUN
# Scientific Scientific PROPN
# Memoirs Memoirs PROPN
# spécialisé spécialisé ADJ
# dans dans ADP
# les le DET
# articles article NOUN
# scientifiques scientifique ADJ
# étrangers étranger ADJ
# . . PUNCT
#
#
#  SPACE
# Elle lui PRON
# passe passer VERB
# neuf neuf ADP
# mois mois NOUN
# , , PUNCT
# entre entre ADP
# 1842 1842 NUM
# et et CCONJ
# 1843 1843 NUM
# , , PUNCT
# sur sur ADP
# cette ce DET
# traduction traduction NOUN
# . . PUNCT
# Babbage babbage NOUN
# lui-même lui-même PRON
# n' n' ADV
# intervient intervenir VERB
# que que ADV
# très très ADV
# peu peu ADV
# , , PUNCT
# étant être AUX
# malade malade ADJ
# pendant pendant ADP
# cette ce DET
# même même ADJ
# période période NOUN
# , , PUNCT
# et et CCONJ
# la le DET
# traduction traduction NOUN
# lui lui PRON
# est être AUX
# présentée présenter VERB
# au au ADP
# début début NOUN
# de de ADP
# l' le DET
# année année NOUN
# 1843 1843 NUM
# un un DET
# peu peu ADV
# comme comme ADP
# un un DET
# « « NOUN
# fait faire AUX
# accompli accomplir VERB
# » » PUNCT
# . . PUNCT
# Il il PRON
# demande demande VERB
# alors alors ADV
# à à ADP
# Ada Ada PROPN
# pourquoi pourquoi ADV
# elle lui PRON
# n' n' ADV
# avait avoir AUX
# pas pas ADV
# fait faire VERB
# elle-même elle-même DET
# un un DET
# mémoire mémoire NOUN
# présentant présenter VERB
# la le DET
# machine machine NOUN
# analytique analytique ADJ
# , , PUNCT
# ce ce PRON
# à à ADP
# quoi quoi PRON
# elle lui PRON
# répondit répondre VERB
# que que SCONJ
# l' le DET
# idée idée NOUN
# ne ne ADV
# lui lui PRON
# était être AUX
# pas pas ADV
# venue venir VERB
# à à ADP
# l' le DET
# esprit esprit NOUN
# . . PUNCT
# Babbage babbage NOUN
# propose propose VERB
# alors alors ADV
# à à ADP
# Ada Ada PROPN
# d' de ADP
# augmenter augmenter VERB
# la le DET
# traduction traduction NOUN
# avec avec ADP
# des un DET
# notes note NOUN
# développant développer VERB
# et et CCONJ
# commentant commenter VERB
# certains certain DET
# aspects aspect NOUN
# du de ADP
# mémoire mémoire NOUN
# , , PUNCT
# idée ider VERB
# immédiatement immédiatement ADV
# adoptée adopter VERB
# avec avec ADP
# enthousiasme enthousiasme NOUN
# par par ADP
# Ada Ada PROPN
# . . PUNCT
#
#
#  SPACE
# S' se PRON
# ensuit ensuit NOUN
# une un DET
# période période NOUN
# de de ADP
# travail travail NOUN
# frénétique frénétique ADJ
# sur sur ADP
# ces ce DET
# notes note NOUN
# , , PUNCT
# en en ADP
# collaboration collaboration NOUN
# étroite étroite VERB
# avec avec ADP
# Charles Charles PROPN
# Babbage Babbage PROPN
# qui qui PRON
# annote annote VERB
# les le DET
# brouillons brouillon NOUN
# , , PUNCT
# corrige corriger VERB
# les le DET
# incompréhensions incompréhension NOUN
# tout tout ADV
# en en ADP
# encourageant encourageant NOUN
# et et CCONJ
# félicitant féliciter VERB
# Ada ada NOUN
# de de ADP
# son son DET
# travail travail NOUN
# . . PUNCT
# Elle lui PRON
# ajoute ajoute VERB
# à à ADP
# cet ce DET
# article article NOUN
# sept sept NUM
# notes note NOUN
# , , PUNCT
# labellisées labelliser VERB
# de de ADP
# A a NOUN
# à à ADP
# G gramme NOUN
# , , PUNCT
# représentant représentant NOUN
# près près ADV
# de de ADP
# trois trois NUM
# fois fois NOUN
# le le DET
# volume volume NOUN
# de de ADP
# texte texte NOUN
# de de ADP
# l' le DET
# article article NOUN
# original original ADJ
# . . PUNCT
# La le DET
# note note NOUN
# G gramme NOUN
# s' se PRON
# appuie appuyer VERB
# sur sur ADP
# un un DET
# véritable véritable ADJ
# algorithme algorithme NOUN
# très très ADV
# détaillé détailler VERB
# pour pour ADP
# calculer calculer VERB
# les le DET
# nombres nombre NOUN
# de de ADP
# Bernoulli Bernoulli PROPN
# avec avec ADP
# la le DET
# machine machine NOUN
# . . PUNCT
# Le le DET
# programme programme NOUN
# qui qui PRON
# en en PRON
# résulte résulte VERB
# est être AUX
# souvent souvent ADV
# considéré considérer VERB
# comme comme ADP
# le le DET
# premier premier ADJ
# véritable véritable ADJ
# programme programme NOUN
# informatique informatique ADJ
# au au ADP
# monde monde NOUN
# , , PUNCT
# car car CCONJ
# les le DET
# algorithmes algorithme NOUN
# décrits décrit NOUN
# jusque-là jusque-là PROPN
# n' n' ADV
# étaient être AUX
# pas pas ADV
# décrits décrire VERB
# avec avec ADP
# un un DET
# formalisme formalisme NOUN
# , , PUNCT
# dans dans ADP
# un un DET
# langage langage NOUN
# véritablement véritablement ADV
# destiné destiner VERB
# à à ADP
# être être AUX
# exécuté exécuter VERB
# sur sur ADP
# une un DET
# machine machine NOUN
# . . PUNCT
# De de ADP
# plus plus ADV
# , , PUNCT
# ce ce DET
# programme programme NOUN
# comporte comporte VERB
# selon selon ADP
# Catherine catherine NOUN
# Dufour dufour ADP
# la le DET
# première premier ADJ
# boucle boucle NOUN
# conditionnelle conditionnel ADJ
# , , PUNCT
# véritable véritable ADJ
# concept concept NOUN
# informatique informatique ADJ
# , , PUNCT
# contrairement contrairement ADV
# aux à ADP
# programmes programme NOUN
# séquentiels séquentiel ADJ
# qui qui PRON
# avaient avoir AUX
# pu pouvoir VERB
# être être AUX
# faits faire VERB
# auparavant auparavant ADV
# par par ADP
# Babbage Babbage PROPN
# , , PUNCT
# ou ou CCONJ
# dans dans ADP
# les le DET
# métiers métier NOUN
# à à ADP
# tisser tisser VERB
# Jacquard Jacquard PROPN
# . . PUNCT
#
#
#  SPACE
# On on PRON
# ne ne ADV
# sait savoir VERB
# pas pas ADV
# exactement exactemer VERB
# dans dans ADP
# quelle quel DET
# mesure mesure NOUN
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# a avoir AUX
# programmé programmer VERB
# elle-même lui-même PRON
# cet ce DET
# algorithme algorithme NOUN
# , , PUNCT
# ayant avoir AUX
# été être AUX
# en en ADP
# relation relation NOUN
# constante constant ADJ
# et et CCONJ
# étroite étroite VERB
# avec avec ADP
# Babbage Babbage PROPN
# . . PUNCT
# Ce ce PRON
# qui qui PRON
# semble semble VERB
# sûr sûr ADJ
# c' ce PRON
# est être VERB
# qu' qu' ADV
# Ada Ada PROPN
# a avoir AUX
# eu avoir VERB
# l' le DET
# idée idée NOUN
# de de ADP
# donner donner VERB
# un un DET
# exemple exemple NOUN
# de de ADP
# programmation programmation NOUN
# de de ADP
# la le DET
# machine machine NOUN
# en en ADP
# utilisant utiliser VERB
# le le DET
# calcul calcul NOUN
# des un DET
# nombres nombre NOUN
# de de ADP
# Bernoulli Bernoulli PROPN
# , , PUNCT
# et et CCONJ
# que que SCONJ
# Babbage Babbage PROPN
# a avoir AUX
# fourni fournir VERB
# à à ADP
# Ada Ada PROPN
# au au ADP
# minimum minimum VERB
# les le DET
# formules formule NOUN
# mathématiques mathématique NOUN
# de de ADP
# base base NOUN
# . . PUNCT
# Selon selon ADP
# Betty Betty PROPN
# Toole Toole PROPN
# , , PUNCT
# Ada Ada PROPN
# était être AUX
# tout tout ADV
# à à ADP
# fait fait NOUN
# en en ADP
# mesure mesure NOUN
# de de ADP
# réaliser réaliser VERB
# elle-même lui-même PRON
# le le DET
# programme programme NOUN
# , , PUNCT
# ayant avoir AUX
# montré montrer VERB
# une un DET
# profonde profonde NOUN
# compréhension compréhension NOUN
# de de ADP
# la le DET
# machine machine NOUN
# dans dans ADP
# sa son DET
# traduction traduction NOUN
# et et CCONJ
# ses son DET
# notes note NOUN
# , , PUNCT
# et et CCONJ
# des de ADP
# lettres lettre NOUN
# entre entre ADP
# Babbage Babbage PROPN
# et et CCONJ
# Ada Ada PROPN
# semblent sembler VERB
# indiquer indiquer VERB
# que que SCONJ
# le le DET
# rôle rôle NOUN
# de de ADP
# Babbage Babbage PROPN
# s' se PRON
# est être AUX
# effectivement effectivement ADV
# limité limité ADJ
# à à ADP
# fournir fournir VERB
# les le DET
# formules formule ADJ
# mathématiques mathématique NOUN
# . . PUNCT
# En en ADP
# revanche revanche NOUN
# , , PUNCT
# Bruce Bruce PROPN
# Collier Collier PROPN
# , , PUNCT
# un un PRON
# des de ADP
# meilleurs meilleur NOUN
# spécialistes spécialiste ADJ
# de de ADP
# la le DET
# machine machine NOUN
# de de ADP
# Babbage Babbage PROPN
# , , PUNCT
# porte porte VERB
# le le DET
# jugement jugement NOUN
# sévère sévère ADJ
# suivant suivant ADJ
# : : PUNCT
# « « PROPN
# Cela cela PRON
# ne ne ADV
# serait être VERB
# qu' qu' ADV
# une un DET
# légère léger ADJ
# exagération exagération NOUN
# de de ADP
# dire dire VERB
# que que SCONJ
# les le DET
# notes note NOUN
# du de ADP
# mémoire mémoire NOUN
# ont avoir AUX
# été être AUX
# écrites écrire VERB
# par par ADP
# Babbage Babbage PROPN
# , , PUNCT
# et et CCONJ
# que que SCONJ
# — — NOUN
# pour pour ADP
# des un DET
# raisons raison NOUN
# qui qui PRON
# lui lui PRON
# sont être AUX
# propres propre ADJ
# — — VERB
# il il PRON
# a avoir AUX
# entretenu entretenir VERB
# l' le DET
# idée idée NOUN
# dans dans ADP
# l' le DET
# esprit esprit NOUN
# d' de ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# , , PUNCT
# et et CCONJ
# dans dans ADP
# l' le DET
# esprit esprit NOUN
# du de ADP
# public public NOUN
# , , PUNCT
# que que SCONJ
# ces ce DET
# notes note NOUN
# étaient être AUX
# d' de ADP
# elle lui PRON
# . . PUNCT
# » » PUNCT
#
#
#
#
#  SPACE
# Selon selon ADP
# Stephen Stephen PROPN
# Wolfram Wolfram PROPN
# , , PUNCT
# on on PRON
# n' n' ADV
# a avoir AUX
# jamais jamais ADV
# retrouvé retrouver VERB
# , , PUNCT
# dans dans ADP
# les le DET
# documents document NOUN
# et et CCONJ
# publications publication NOUN
# de de ADP
# Babbage Babbage PROPN
# , , PUNCT
# des un DET
# algorithmes algorithme NOUN
# aussi aussi ADV
# complexes complexe NOUN
# et et CCONJ
# aussi aussi ADV
# propres propre ADJ
# que que SCONJ
# celui celui PRON
# sous-jacent sous-jacer VERB
# au au ADP
# programme programme NOUN
# de de ADP
# calcul calcul NOUN
# des un DET
# nombres nombre NOUN
# de de ADP
# Bernoulli Bernoulli PROPN
# . . PUNCT
# Babbage babbage NOUN
# , , PUNCT
# à à ADP
# la le DET
# fin fin NOUN
# de de ADP
# sa son DET
# vie vie NOUN
# , , PUNCT
# avait avoir AUX
# compilé compiler VERB
# une un DET
# liste liste NOUN
# datée dater VERB
# de de ADP
# 446 446 NUM
# calculs calcul NOUN
# possibles possible ADJ
# avec avec ADP
# sa son DET
# machine machine NOUN
# analytique analytique ADJ
# ( ( PUNCT
# 446 446 NUM
# Notations Notations PROPN
# of of X
# the the X
# Analytical Analytical PROPN
# Engine Engine PROPN
# ) ) PUNCT
# , , PUNCT
# tous tout ADJ
# datés daté NOUN
# de de ADP
# 1830 1830 NUM
# à à ADP
# mi mi ADP
# 1840 1840 NUM
# , , PUNCT
# date date NOUN
# après après ADP
# laquelle lequel PRON
# on on PRON
# ne ne ADV
# trouve trouve VERB
# plus plus ADV
# de de DET
# travaux travail NOUN
# de de ADP
# Babbage Babbage PROPN
# sur sur ADP
# les le DET
# algorithmes algorithme NOUN
# . . PUNCT
# Ces ce DET
# éléments élément NOUN
# laissent laisser VERB
# penser penser VERB
# qu' que SCONJ
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# a avoir AUX
# conçu concevoir VERB
# ce ce DET
# programme programme NOUN
# , , PUNCT
# avec avec ADP
# la le DET
# simple simple ADJ
# supervision supervision NOUN
# bienveillante bienveillant ADJ
# de de ADP
# Babbage Babbage PROPN
# . . PUNCT
#
#
#  SPACE
# Dans dans ADP
# d' d' DET
# autres autre ADJ
# notes note NOUN
# , , PUNCT
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# montre montre VERB
# une un DET
# perception perception NOUN
# des de ADP
# potentialités potentialité NOUN
# de de ADP
# la le DET
# machine machine NOUN
# que que PRON
# Doron Doron PROPN
# Swade Swade PROPN
# considère considèr ADJ
# comme comme ADP
# « « ADJ
# visionnaire visionnaire NOUN
# , , PUNCT
# même même ADV
# dans dans ADP
# une un DET
# perspective perspective NOUN
# moderne moderne ADJ
# » » PUNCT
# . . PUNCT
# Babbage babbage NOUN
# avait avoir AUX
# une un DET
# vision vision NOUN
# de de ADP
# sa son DET
# machine machine NOUN
# comme comme ADP
# étant être AUX
# tournée tourner VERB
# vers vers ADP
# le le DET
# calcul calcul NOUN
# numérique numérique ADJ
# , , PUNCT
# avec avec ADP
# à à ADP
# la le DET
# limite limite NOUN
# des de ADP
# extensions extension NOUN
# vers vers ADP
# le le DET
# calcul calcul NOUN
# algébrique algébrique ADJ
# avec avec ADP
# la le DET
# possibilité possibilité NOUN
# de de ADP
# manipuler manipuler VERB
# des un DET
# symboles symbole NOUN
# plutôt plutôt ADV
# que que SCONJ
# des un DET
# chiffres chiffre NOUN
# . . PUNCT
# Mais mais CCONJ
# il il PRON
# n' n' ADV
# a avoir VERB
# rien rien PRON
# publié publier VERB
# allant aller VERB
# dans dans ADP
# ce ce DET
# sens sens NOUN
# , , PUNCT
# et et CCONJ
# il il PRON
# n' n' ADV
# a avoir AUX
# pas pas ADV
# approfondi approfondir VERB
# cette ce DET
# possibilité possibilité NOUN
# , , PUNCT
# allant aller VERB
# même même ADV
# jusqu' jusque ADP
# à à ADP
# imaginer imaginer VERB
# un un DET
# autre autre ADJ
# type type NOUN
# de de ADP
# machine machine NOUN
# spécifique spécifique ADJ
# pour pour ADP
# les le DET
# calculs calcul NOUN
# algébriques algébrique ADJ
# . . PUNCT
# En en ADP
# revanche revanche NOUN
# , , PUNCT
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# décrit décrire VERB
# explicitement explicitement ADV
# des de ADP
# possibilités possibilité NOUN
# allant aller VERB
# au-delà au-delà ADV
# d' de ADP
# un un DET
# contexte contexte NOUN
# mathématique mathématique ADJ
# , , PUNCT
# comme comme ADP
# l' le DET
# hypothèse hypothèse NOUN
# que que SCONJ
# « « VERB
# la le DET
# machine machine NOUN
# pourrait pouvoir VERB
# composer composer VERB
# de de ADP
# manière manière NOUN
# scientifique scientifique ADJ
# et et CCONJ
# élaborée élaborer VERB
# des de ADP
# morceaux morceau NOUN
# de de ADP
# musique musique NOUN
# de de ADP
# n' n' ADV
# importe importe VERB
# quelle quel DET
# longueur longueur NOUN
# ou ou CCONJ
# degré degré ADJ
# de de ADP
# complexité complexité NOUN
# » » ADJ
# . . PUNCT
#
#
#
#
#  SPACE
# Un un DET
# autre autre ADJ
# passage passage NOUN
# des de ADP
# notes note NOUN
# d' de ADP
# Ada Ada PROPN
# , , PUNCT
# cité cité NOUN
# par par ADP
# Doron Doron PROPN
# Swade Swade PROPN
# , , PUNCT
# illustre illustre VERB
# cette ce DET
# vision vision NOUN
# de de ADP
# calculateur calculateur NOUN
# universel universel VERB
# : : PUNCT
#
#
#  SPACE
# « « PROPN
# Beaucoup Beaucoup PROPN
# de de ADP
# personnes personne NOUN
# [ [ PUNCT
# … … DET
# ] ] PUNCT
# s' se PRON
# imaginent imaginer VERB
# que que SCONJ
# parce parce SCONJ
# que que SCONJ
# la le DET
# Machine Machine PROPN
# fournit fournir VERB
# des de ADP
# résultats résultat NOUN
# sous sous ADP
# une un DET
# forme forme NOUN
# numérique numérique ADJ
# , , PUNCT
# alors alors ADV
# la le DET
# nature nature NOUN
# de de ADP
# ses son DET
# processus processus NOUN
# doit devoir VERB
# être être AUX
# forcément forcémer VERB
# arithmétique arithmétique ADJ
# et et CCONJ
# numérique numérique ADJ
# , , PUNCT
# plutôt plutôt ADV
# qu' que SCONJ
# algébrique algébrique ADJ
# ou ou CCONJ
# analytique analytique ADJ
# . . PUNCT
# Ceci ceci PRON
# est être AUX
# une un DET
# erreur erreur NOUN
# . . PUNCT
# La le DET
# Machine Machine PROPN
# peut pouvoir VERB
# arranger arranger VERB
# et et CCONJ
# combiner combiner VERB
# les le DET
# quantités quantité NOUN
# numériques numérique ADJ
# exactement exactemer VERB
# comme comme SCONJ
# si si SCONJ
# elles lui PRON
# étaient être VERB
# des un DET
# lettres lettre NOUN
# , , PUNCT
# ou ou CCONJ
# tout tout DET
# autre autre ADJ
# symbole symbole NOUN
# général général ADJ
# ; ; PUNCT
# en en ADP
# fait faire VERB
# elle lui PRON
# peut pouvoir VERB
# donner donner VERB
# des un DET
# résultats résultat NOUN
# en en ADP
# notation notation NOUN
# algébrique algébrique ADJ
# , , PUNCT
# avec avec ADP
# des un DET
# conventions convention NOUN
# appropriées approprié ADJ
# . . PUNCT
# » » PUNCT
#
#
#
#
#   SPACE
# Il il PRON
# fallut falloir VERB
# attendre attendre VERB
# les le DET
# années année NOUN
# 1930 1930 NUM
# avec avec ADP
# Alan Alan PROPN
# Turing Turing PROPN
# pour pour ADP
# formaliser formaliser VERB
# une un DET
# telle tel ADJ
# notion notion NOUN
# de de ADP
# calculateur calculateur NOUN
# universel universel ADJ
# qui qui PRON
# manipule manipule VERB
# des de ADP
# symboles symbole NOUN
# généraux général ADJ
# , , PUNCT
# et et CCONJ
# abandonner abandonner VERB
# la le DET
# notion notion NOUN
# de de ADP
# calculatrice calculatrice NOUN
# purement purement ADV
# numérique numérique ADJ
# . . PUNCT
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = X
# = = PRON
# Ruine Ruine PROPN
# et et CCONJ
# mort mort NOUN
# = = AUX
# = = X
# = = X
#
#
#  SPACE
# Dans dans ADP
# l’ l’ SPACE
# espoir espoir NOUN
# de de ADP
# subventionner subventionner VERB
# les le DET
# projets projet NOUN
# de de ADP
# Babbage Babbage PROPN
# , , PUNCT
# qui qui PRON
# n' n' ADV
# avaient avoir AUX
# pas pas ADV
# obtenu obtenir VERB
# de de ADP
# financement financement NOUN
# du de ADP
# gouvernement gouvernement NOUN
# britannique britannique ADJ
# , , PUNCT
# Lady Lady PROPN
# Lovelace Lovelace PROPN
# se se PRON
# mit mettre VERB
# à à ADP
# jouer jouer VERB
# . . PUNCT
# Elle lui PRON
# travailla travailler VERB
# à à ADP
# un un DET
# système système NOUN
# qui qui PRON
# devait devoir VERB
# lui lui PRON
# permettre permettre VERB
# de de ADP
# remporter remporter VERB
# les le DET
# paris pari PROPN
# du de ADP
# derby derby NOUN
# d' de ADP
# Epsom Epsom PROPN
# mais mais CCONJ
# ne ne ADV
# l' le DET
# entraîna entraîna NOUN
# que que SCONJ
# dans dans ADP
# l' le DET
# accumulation accumulation NOUN
# de de ADP
# dettes dette NOUN
# . . PUNCT
#
#
#  SPACE
# Elle Elle PROPN
# mourut mourir VERB
# à à ADP
# l' le DET
# âge âge NOUN
# de de ADP
# 36 36 NUM
# ans an NOUN
# d' de ADP
# un un DET
# cancer cancer NOUN
# de de ADP
# l' le DET
# utérus utérus NOUN
# , , PUNCT
# dans dans ADP
# d' d' DET
# horribles horrible NOUN
# souffrances souffrance ADJ
# . . PUNCT
# Elle lui PRON
# laissait laisser VERB
# deux deux NUM
# fils fils NOUN
# et et CCONJ
# une un DET
# fille fille NOUN
# . . PUNCT
# Cette ce DET
# dernière dernier ADJ
# , , PUNCT
# Anne ann ADJ
# Blunt Blunt PROPN
# , , PUNCT
# est être AUX
# connue connaître VERB
# pour pour ADP
# avoir avoir AUX
# voyagé voyager VERB
# au au ADP
# Moyen-Orient Moyen-Orient PROPN
# et et CCONJ
# pour pour ADP
# avoir avoir AUX
# élevé élevé ADJ
# des de ADP
# chevaux cheval NOUN
# arabes arabe NOUN
# . . PUNCT
#
#
#  SPACE
# Elle lui PRON
# fut être AUX
# enterrée enterrer VERB
# conformément conformément ADV
# à à ADP
# son son DET
# souhait souhait NOUN
# près près ADV
# de de ADP
# son son DET
# père père NOUN
# qu' que SCONJ
# elle lui PRON
# n' n' ADV
# avait avoir AUX
# jamais jamais ADV
# connu connaître VERB
# , , PUNCT
# à à ADP
# l' le DET
# église église NOUN
# Sainte-Marie-Magdalene Sainte-Marie-Magdalene PROPN
# de de ADP
# Hucknall Hucknall PROPN
# , , PUNCT
# à à ADP
# Newstead Newstead PROPN
# Abbey Abbey PROPN
# , , PUNCT
# dans dans ADP
# le le DET
# comté comté NOUN
# de de ADP
# Nottingham Nottingham PROPN
# . . PUNCT
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = X
# = = X
# Notoriété Notoriété PROPN
# posthume posthume PROPN
# = = AUX
# = = PRON
# = = X
#
#
#  SPACE
# Tombée Tombée PROPN
# dans dans ADP
# l' le DET
# oubli oubli NOUN
# , , PUNCT
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# et et CCONJ
# ses son DET
# travaux travail NOUN
# furent être AUX
# exhumés exhumer VERB
# avec avec ADP
# l' le DET
# avènement avènement NOUN
# de de ADP
# l' le DET
# informatique informatique ADJ
# . . PUNCT
# Et et CCONJ
# c' ce PRON
# est être AUX
# en en ADP
# son son DET
# hommage hommage NOUN
# qu' qu' PRON
# on on PRON
# a avoir AUX
# appelé appeler VERB
# Ada Ada PROPN
# le le DET
# langage langage NOUN
# de de ADP
# programmation programmation NOUN
# conçu concevoir VERB
# entre entre ADP
# 1977 1977 NUM
# et et CCONJ
# 1983 1983 NUM
# pour pour ADP
# le le DET
# département département NOUN
# de de ADP
# la le DET
# Défense défense NOUN
# américain américain ADJ
# ( ( PUNCT
# DoD DoD X
# ) ) PUNCT
# par par ADP
# une un DET
# équipe équipe NOUN
# de de ADP
# CII CII PROPN
# Honeywell Honeywell PROPN
# Bull Bull PROPN
# dirigée diriger VERB
# par par ADP
# le le DET
# Français français NOUN
# Jean Jean PROPN
# Ichbiah Ichbiah PROPN
# . . PUNCT
# L' le DET
# idée idée NOUN
# de de ADP
# choisir choisir NOUN
# le le DET
# nom nom NOUN
# Ada Ada PROPN
# est être AUX
# attribuée attribuer VERB
# à à ADP
# Jack Jack PROPN
# Cooper Cooper PROPN
# , , PUNCT
# du de ADP
# Naval Naval PROPN
# Material Material PROPN
# Command Command PROPN
# , , PUNCT
# et et CCONJ
# remonte remonte VERB
# à à ADP
# juillet juillet NOUN
# 1978[réf 1978[réf NUM
# . . PUNCT
# nécessaire]. nécessaire]. VERB
#
#
#  SPACE
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# est être AUX
# considérée considérer VERB
# par par ADP
# les le DET
# historiens historien NOUN
# de de ADP
# l' le DET
# informatique informatique ADJ
# comme comme ADP
# la le DET
# première premier ADJ
# personne personne NOUN
# à à ADP
# avoir avoir AUX
# programmé programmer VERB
# de de ADP
# l' le DET
# histoire histoire NOUN
# . . PUNCT
# On on PRON
# peut pouvoir VERB
# voir voir VERB
# notamment notamment ADV
# son son DET
# portrait portrait NOUN
# sur sur ADP
# les le DET
# hologrammes hologramme NOUN
# d' de ADP
# authentification authentification NOUN
# des de ADP
# produits produit NOUN
# Microsoft microsoft ADJ
# . . PUNCT
#
#
#  SPACE
# L' le DET
# entreprise entreprise NOUN
# Nvidia Nvidia PROPN
# a avoir AUX
# également également ADV
# décidé décider VERB
# de de ADP
# nommer nommer VERB
# sa son DET
# nouvelle nouveau ADJ
# architecture architecture NOUN
# graphique graphique ADJ
# sous sous ADP
# le le DET
# nom nom NOUN
# de de ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# , , PUNCT
# pour pour ADP
# sa son DET
# nouvelle nouveau ADJ
# série série NOUN
# de de ADP
# cartes carte NOUN
# graphiques graphique ADJ
# RTX rt NOUN
# 4000 4000 NUM
# . . PUNCT
#
#
#  SPACE
# L' le DET
# astéroïde astéroïde NOUN
# ( ( PUNCT
# 232923 232923 NUM
# ) ) PUNCT
# Adalovelace Adalovelace PROPN
# porte porte VERB
# son son DET
# nom nom NOUN
# . . PUNCT
#
#
#
#
#
#
#  SPACE
# = = NOUN
# = = VERB
# Dans dans ADP
# la le DET
# fiction fiction NOUN
# = = AUX
# = = X
#
#
#  SPACE
# Ada Ada PROPN
# est être AUX
# l' le DET
# un un PRON
# des de ADP
# personnages personnage NOUN
# principaux principal ADJ
# de de ADP
# l' le DET
# histoire histoire NOUN
# alternative alternatif ADJ
# La le DET
# Machine Machine PROPN
# à à ADP
# différences différence NOUN
# de de ADP
# Bruce Bruce PROPN
# Sterling Sterling PROPN
# et et CCONJ
# William William PROPN
# Gibson Gibson PROPN
# , , PUNCT
# qui qui PRON
# décrit décrire VERB
# un un DET
# monde monde NOUN
# dans dans ADP
# lequel lequel PRON
# la le DET
# machine machine NOUN
# de de ADP
# Babbage Babbage PROPN
# aurait avoir AUX
# été être AUX
# produite produire VERB
# de de ADP
# manière manière NOUN
# industrielle industriel ADJ
# et et CCONJ
# où où PRON
# l' le DET
# ère ère NOUN
# informatique informatique ADJ
# aurait avoir AUX
# commencé commencer VERB
# un un DET
# siècle siècle NOUN
# plus plus ADV
# tôt tôt ADV
# . . PUNCT
#
#
#  SPACE
# Le le DET
# film film NOUN
# Conceiving Conceiving PROPN
# Ada Ada PROPN
# ( ( PUNCT
# en en NOUN
# ) ) PUNCT
# ( ( PUNCT
# 1997 1997 NUM
# ) ) PUNCT
# , , PUNCT
# réalisé réaliser VERB
# par par ADP
# Lynn Lynn PROPN
# Hershman Hershman PROPN
# Leeson Leeson PROPN
# , , PUNCT
# établit établir VERB
# un un DET
# parallèle parallèle NOUN
# entre entre ADP
# l' le DET
# existence existence NOUN
# d' de ADP
# une un DET
# Britannique Britannique PROPN
# contemporaine contemporaine VERB
# et et CCONJ
# la le DET
# biographie biographie NOUN
# d' de ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# ( ( PUNCT
# interprétée interpréter VERB
# par par ADP
# Tilda tilda NOUN
# Swinton Swinton PROPN
# ) ) PUNCT
# . . PUNCT
#
#
#  SPACE
# Le le DET
# personnage personnage NOUN
# d' de ADP
# Ada Ada PROPN
# , , PUNCT
# une un DET
# petite petit ADJ
# fille fille NOUN
# douée douer VERB
# en en ADP
# mathématiques mathématique NOUN
# , , PUNCT
# dans dans ADP
# la le DET
# bande bande NOUN
# dessinée dessiner VERB
# Nombre Nombre PROPN
# , , PUNCT
# par par ADP
# Egger Egger PROPN
# et et CCONJ
# Thierry Thierry PROPN
# Smolderen Smolderen PROPN
# , , PUNCT
# est être AUX
# un un DET
# clin clin NOUN
# d' de ADP
# œil œil NOUN
# à à ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# . . PUNCT
#
#
#  SPACE
# Le le DET
# personnage personnage NOUN
# de de ADP
# Ada Ada PROPN
# Enigma Enigma PROPN
# , , PUNCT
# jeune jeune ADJ
# fille fille NOUN
# libre libre ADJ
# et et CCONJ
# indépendante indépendant ADJ
# , , PUNCT
# dans dans ADP
# la le DET
# série série NOUN
# homonyme homonyme ADJ
# , , PUNCT
# par par ADP
# Vincent Vincent PROPN
# Dutreuil dutreuil NOUN
# et et CCONJ
# François François PROPN
# Maingoval Maingoval PROPN
# , , PUNCT
# doit devoir VERB
# son son DET
# nom nom NOUN
# à à ADP
# un un DET
# clin clin NOUN
# d' de ADP
# œil œil NOUN
# à à ADP
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# et et CCONJ
# à à ADP
# la le DET
# machine machine NOUN
# Enigma Enigma PROPN
# . . PUNCT
#
#
#  SPACE
# Le le DET
# nom nom NOUN
# d' de ADP
# Ada Ada PROPN
# Byron Byron PROPN
# a avoir AUX
# été être AUX
# choisi choisir VERB
# par par ADP
# la le DET
# 37e 37 ADJ
# promotion promotion NOUN
# ( ( PUNCT
# 2007 2007 NOUN
# - - NOUN
# 2008 2008 NOUN
# ) ) PUNCT
# des un DET
# élèves élève NOUN
# attachés attaché NOUN
# chargés charger ADJ
# du de ADP
# traitement traitement NOUN
# de de ADP
# l' le DET
# information information NOUN
# de de ADP
# l' le DET
# IRA ira NOUN
# ( ( PUNCT
# Institut Institut PROPN
# régional régional ADJ
# d' de ADP
# administration administration NOUN
# ) ) PUNCT
# de de ADP
# Lille Lille PROPN
# . . PUNCT
#
#
#  SPACE
# ADA ada NOUN
# est être AUX
# le le DET
# nom nom NOUN
# de de ADP
# l' le DET
# intelligence intelligence NOUN
# artificielle artificiel ADJ
# qui qui PRON
# copilote copilote VERB
# le le DET
# robot robot NOUN
# Jehuty Jehuty PROPN
# dans dans ADP
# le le DET
# jeu jeu NOUN
# vidéo vidéo NOUN
# Zone zone VERB
# of of X
# the the X
# Enders Enders X
# , , PUNCT
# la le DET
# voix voix NOUN
# synthétique synthétique ADJ
# d' de ADP
# ADA ADA PROPN
# ayant avoir VERB
# une un DET
# tessiture tessiture NOUN
# féminine féminin ADJ
# . . PUNCT
#
#
#  SPACE
# Lady Lady X
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# est être AUX
# un un DET
# personnage personnage NOUN
# expert expert ADJ
# en en ADP
# machine machine NOUN
# de de ADP
# calcul calcul NOUN
# et et CCONJ
# une un DET
# thaumaturge thaumaturge NOUN
# émérite émérite NOUN
# dans dans ADP
# le le DET
# jeu jeu NOUN
# de de ADP
# rôle rôle NOUN
# steampunk steampunk ADJ
# Castle Castle PROPN
# Falkenstein Falkenstein PROPN
# de de ADP
# Mike Mike PROPN
# Pondsmith Pondsmith PROPN
# . . PUNCT
#
#
#  SPACE
# Lovelace Lovelace PROPN
# ( ( PUNCT
# Lovey Lovey PROPN
# ) ) PUNCT
# est être AUX
# une un DET
# intelligence intelligence NOUN
# artificielle artificiel ADJ
# , , PUNCT
# personnage personnage NOUN
# à à ADP
# part part NOUN
# entière entier ADJ
# du de ADP
# roman roman NOUN
# L' le DET
# Espace Espace PROPN
# d' de ADP
# un un DET
# an an NOUN
# , , PUNCT
# de de ADP
# Becky Becky PROPN
# Chambers Chambers PROPN
# . . PUNCT
#
#
#  SPACE
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# , , PUNCT
# d' de ADP
# abord abord ADV
# présentée présenter VERB
# sous sous ADP
# son son DET
# nom nom NOUN
# de de ADP
# jeune jeune ADJ
# fille fille NOUN
# Ada Ada PROPN
# Gordon Gordon X
# ( ( PUNCT
# car car CCONJ
# l' le DET
# action action NOUN
# la le PRON
# concernant concerner VERB
# se se PRON
# déroule déroule VERB
# en en ADP
# 1834 1834 NUM
# ) ) PUNCT
# , , PUNCT
# apparaît apparaître VERB
# dans dans ADP
# l' le DET
# épisode épisode NOUN
# 2 2 NUM
# de de ADP
# la le DET
# saison saison NOUN
# 12 12 NUM
# de de ADP
# Doctor Doctor PROPN
# Who Who PROPN
# , , PUNCT
# La le DET
# Chute chute NOUN
# des de ADP
# espions espion NOUN
# : : PUNCT
# partie partie NOUN
# 2 2 NUM
# . . PUNCT
# Elle lui PRON
# accompagne accompagne VERB
# le le DET
# Docteur docteur NOUN
# à à ADP
# travers travers NOUN
# diverses divers ADJ
# époques époque NOUN
# ( ( PUNCT
# la le DET
# sienne sienne NOUN
# , , PUNCT
# 1943 1943 NUM
# et et CCONJ
# le le DET
# présent présent NOUN
# ) ) PUNCT
# pour pour ADP
# lutter lutter VERB
# face face NOUN
# à à ADP
# une un DET
# crise crise NOUN
# mondiale mondial ADJ
# menée mener VERB
# par par ADP
# le le DET
# Maître maître NOUN
# . . PUNCT
#
#
#  SPACE
# Ada Ada PROPN
# , , PUNCT
# présentée présenter VERB
# comme comme ADP
# programmeuse programmeus ADJ
# , , PUNCT
# est être AUX
# l' le DET
# un un PRON
# des de ADP
# personnages personnage NOUN
# principaux principal ADJ
# de de ADP
# la le DET
# trilogie trilogie NOUN
# Arena arena NOUN
# 13 13 NUM
# de de ADP
# Joseph Joseph PROPN
# Delaney Delaney PROPN
# . . PUNCT
#
#
#  SPACE
# Son son DET
# personnage personnage NOUN
# apparaît apparaître VERB
# dans dans ADP
# le le DET
# 2e 2e NOUN
# épisode épisode NOUN
# de de ADP
# la le DET
# saison saison NOUN
# 2 2 NUM
# de de ADP
# la le DET
# série série NOUN
# télévisée téléviser VERB
# Victoria Victoria PROPN
# , , PUNCT
# interprété interpréter VERB
# par par ADP
# Emerald Emerald PROPN
# Fennell Fennell PROPN
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = PRON
# Notes note NOUN
# et et CCONJ
# références référence NOUN
# = = AUX
# = = X
#
#
#
#
#
#
#  SPACE
# = = NOUN
# = = PRON
# Annexes Annexes PROPN
# = = X
# = = X
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = X
# = = PRON
# Bibliographie bibliographie NOUN
# = = AUX
# = = X
# = = X
#
#
#  SPACE
# ( ( PUNCT
# en en X
# ) ) PUNCT
# Benjamin Benjamin PROPN
# Woolley Woolley PROPN
# , , PUNCT
# The The X
# Bride Bride X
# of of ADP
# Science Science PROPN
# : : PUNCT
# Romance romance NOUN
# , , PUNCT
# Reason Reason PROPN
# , , PUNCT
# and and X
# Byron' Byron' X
# s s PRON
# Daughter daughter VERB
# , , PUNCT
# McGraw McGraw PROPN
# - - PROPN
# Hill Hill PROPN
# , , PUNCT
# 1999 1999 NUM
# : : PUNCT
#
#
#  SPACE
# ( ( PUNCT
# en en X
# ) ) PUNCT
# Dorothy Dorothy PROPN
# Stein Stein PROPN
# , , PUNCT
# Ada Ada PROPN
# : : PUNCT
# A avoir AUX
# Life Life X
# and and X
# a avoir X
# Legacy Legacy PROPN
# , , PUNCT
# Cambridge Cambridge PROPN
# , , PUNCT
# Mass mas NOUN
# . . PUNCT
# , , PUNCT
# The The X
# MIT MIT PROPN
# Press Press PROPN
# , , PUNCT
# 1985 1985 NUM
# ( ( PUNCT
# ISBN isbn NOUN
# 0 0 NUM
# - - NOUN
# 262 262 NOUN
# - - NOUN
# 19242-X 19242- NOUN
# ) ) PUNCT
# : : PUNCT
#
#
#  SPACE
# ( ( PUNCT
# en en X
# ) ) PUNCT
# Doron Doron X
# Swade Swade PROPN
# , , PUNCT
# The The X
# Difference Difference X
# Engine Engine PROPN
# : : PUNCT
# Charles Charles PROPN
# Babbage Babbage PROPN
# and and X
# the the X
# Quest quest AUX
# to to X
# Build Build PROPN
# the the X
# First First X
# Computer computer VERB
# , , PUNCT
# Penguin Penguin PROPN
# ( ( PUNCT
# Non-Classics non-classic NOUN
# ) ) PUNCT
# , , PUNCT
# 2002 2002 NUM
# : : PUNCT
#
#
#  SPACE
# ( ( PUNCT
# en en X
# ) ) PUNCT
# Bruce Bruce PROPN
# Collier Collier PROPN
# , , PUNCT
# Charles Charles PROPN
# Babbage Babbage PROPN
# and and X
# the the X
# Engines Engines X
# of of X
# Perfection perfection NOUN
# , , PUNCT
# Oxford Oxford PROPN
# University University PROPN
# Press Press PROPN
# , , PUNCT
# 1998 1998 NUM
# : : PUNCT
#
#
#  SPACE
# ( ( PUNCT
# en en NOUN
# ) ) PUNCT
# Betty Betty PROPN
# Toole Toole PROPN
# , , PUNCT
# Ada Ada X
# and and X
# the the X
# first first VERB
# computer computer VERB
# , , PUNCT
# Scientific Scientific PROPN
# American American PROPN
# , , PUNCT
# 1999 1999 NUM
# ( ( PUNCT
# lire lire VERB
# en en ADP
# ligne ligne NOUN
# ) ) PUNCT
# : : PUNCT
#
#
#  SPACE
# Stephen Stephen PROPN
# Wolfram Wolfram PROPN
# ( ( PUNCT
# en en NOUN
# ) ) PUNCT
# « « PROPN
# Untangling Untangling X
# the the X
# Tale Tale X
# of of X
# Ada Ada X
# Lovelace Lovelace PROPN
# » » PUNCT
# , , PUNCT
# sur sur ADP
# http://blog.stephenwolfram.com http://blog.stephenwolfram.com PROPN
# : : PUNCT
#
#
#  SPACE
# Jean-Paul Jean-Paul PROPN
# Soyer Soyer PROPN
# , , PUNCT
# Ada Ada PROPN
# de de ADP
# Lovelace Lovelace PROPN
# et et CCONJ
# la le DET
# programmation programmation NOUN
# informatique informatique ADJ
# , , PUNCT
# éd éd PROPN
# . . PUNCT
# du de ADP
# Sorbier Sorbier PROPN
# , , PUNCT
# Paris Paris PROPN
# , , PUNCT
# 1998 1998 NUM
# , , PUNCT
# 31 31 NUM
# p. p. NOUN
#     SPACE
# ( ( PUNCT
# ISBN isbn NOUN
# 2 2 NOUN
# - - NOUN
# 7320 7320 NOUN
# - - NOUN
# 3539 3539 NOUN
# - - NOUN
# 4 4 NOUN
# ) ) PUNCT
#
#
#  SPACE
# Dorothy Dorothy PROPN
# Stein Stein PROPN
# , , PUNCT
# Ada Ada PROPN
# Byron Byron PROPN
# : : PUNCT
# la le DET
# comète comète NOUN
# et et CCONJ
# le le DET
# génie génie NOUN
# ( ( PUNCT
# trad trad NOUN
# . . PUNCT
# de de ADP
# Ada Ada PROPN
# Byron Byron PROPN
# , , PUNCT
# a avoir AUX
# life life X
# and and X
# a avoir X
# legacy legacy X
# , , PUNCT
# par par ADP
# Maurice Maurice PROPN
# Gabail Gabail PROPN
# ) ) PUNCT
# , , PUNCT
# Seghers segher NOUN
# , , PUNCT
# Paris Paris PROPN
# , , PUNCT
# 1990 1990 NUM
# , , PUNCT
# 367 367 NUM
# p. p. NOUN
#     SPACE
# ( ( PUNCT
# ISBN isbn NOUN
# 2 2 NOUN
# - - NOUN
# 232 232 NOUN
# - - NOUN
# 10145 10145 NOUN
# - - NOUN
# 2 2 NOUN
# ) ) PUNCT
#
#
#  SPACE
# ( ( PUNCT
# en en NOUN
# ) ) PUNCT
# Betty Betty PROPN
# Alexandra Alexandra PROPN
# Toole Toole PROPN
# , , PUNCT
# Ada Ada PROPN
# , , PUNCT
# the the X
# enchantress enchantress X
# of of ADP
# numbers numbers VERB
# , , PUNCT
# prophet prophet VERB
# of of ADP
# the the X
# computer computer VERB
# age age NOUN
# : : PUNCT
# a avoir AUX
# pathway pathway VERB
# to to PRON
# the the X
# 21st 21st X
# century century NOUN
# , , PUNCT
# Strawberry Strawberry PROPN
# Press Press PROPN
# , , PUNCT
# Mill Mill PROPN
# Valley Valley PROPN
# ( ( PUNCT
# Calif Calif PROPN
# . . PUNCT
# ) ) PUNCT
# , , PUNCT
# 1998 1998 NUM
# , , PUNCT
# 323 323 NUM
# p. p. NOUN
#     SPACE
# ( ( PUNCT
# ISBN isbn NOUN
# 0 0 NUM
# - - NOUN
# 912647 912647 NOUN
# - - NOUN
# 18 18 NOUN
# - - NOUN
# 3 3 NOUN
# ) ) PUNCT
# ( ( PUNCT
# contient contenir VERB
# une un DET
# sélection sélection NOUN
# de de ADP
# sa son DET
# correspondance correspondance NOUN
# ) ) PUNCT
#
#
#  SPACE
# Catherine catherine NOUN
# Dufour Dufour PROPN
# , , PUNCT
# Ada Ada PROPN
# ou ou CCONJ
# la le DET
# beauté beauté NOUN
# des de ADP
# nombres nombre NOUN
# : : PUNCT
# La le DET
# pionnière pionnier NOUN
# de de ADP
# l' le DET
# informatique informatique ADJ
# , , PUNCT
# Librairie Librairie PROPN
# Arthème Arthème PROPN
# Fayard Fayard PROPN
# , , PUNCT
# 4 4 NUM
# septembre septembre NOUN
# 2019 2019 NUM
# , , PUNCT
# 244 244 NUM
# p. p. NOUN
# ( ( PUNCT
# ISBN isbn NOUN
# 2 2 NOUN
# - - NOUN
# 213 213 NOUN
# - - NOUN
# 71279 71279 NOUN
# - - NOUN
# 4 4 NOUN
# ) ) PUNCT
#
#
#  SPACE
# Jean-Luc Jean-Luc PROPN
# Dousset Dousset PROPN
# , , PUNCT
# Ada Ada PROPN
# 1.0 1.0 NUM
# La le DET
# fille fille NOUN
# de de ADP
# Byron Byron PROPN
# lance lance NOUN
# le le DET
# premier premier ADJ
# programme programme NOUN
# informatique informatique ADJ
# , , PUNCT
# éditions édition NOUN
# Jeanne Jeanne PROPN
# d' de ADP
# Arc Arc PROPN
# , , PUNCT
# 2021 2021 NUM
# . . PUNCT
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = X
# = = PRON
# Articles Articles PROPN
# connexes connexe ADJ
# = = AUX
# = = X
# = = X
#
#
#  SPACE
# Histoire histoire NOUN
# de de ADP
# l' le DET
# informatique informatique ADJ
#
#
#  SPACE
# Ada Ada PROPN
# ( ( PUNCT
# langage langage NOUN
# ) ) PUNCT
#
#
#  SPACE
# Ada Ada PROPN
# Initiative Initiative PROPN
#
#
#  SPACE
# Famille Famille PROPN
# Byron Byron PROPN
#
#
#  SPACE
# Liste liste NOUN
# des de ADP
# premières premier ADJ
# femmes femme NOUN
# par par ADP
# fonction fonction NOUN
# ou ou CCONJ
# titre titre NOUN
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = X
# = = PRON
# Liens lien NOUN
# externes externe ADJ
# = = AUX
# = = X
# = = X
#
#
#  SPACE
# « « PROPN
# Prénom prénom NOUN
# de de ADP
# code code NOUN
# : : PUNCT
# ADA ada NOUN
# » » PUNCT
# , , PUNCT
# La le DET
# Conversation conversation NOUN
# scientifique scientifique ADJ
# , , PUNCT
# France France PROPN
# Culture Culture PROPN
# , , PUNCT
# 22 22 NUM
# août août NOUN
# 2021 2021 NUM
# . . PUNCT
#
#
#  SPACE
# « « PROPN
# Ada Ada PROPN
# Lovelace Lovelace PROPN
# , , PUNCT
# la le DET
# grande grand ADJ
# ordinatrice ordinatrice NOUN
# » » PUNCT
# , , PUNCT
# La le DET
# Méthode Méthode PROPN
# scientifique scientifique ADJ
# , , PUNCT
# France France PROPN
# Culture Culture PROPN
# , , PUNCT
# 26 26 NUM
# septembre septembre NOUN
# 2019 2019 NUM
# . . PUNCT
#
#
#  SPACE
# ( ( PUNCT
# en en X
# ) ) PUNCT
# Sketch Sketch PROPN
# of of X
# the the X
# Analytical Analytical X
# Engine Engine PROPN
# Invented Invented PROPN
# by by ADP
# Charles Charles PROPN
# Babbage Babbage PROPN
# , , PUNCT
# Esq esq NOUN
# . . PUNCT
# avec avec ADP
# des un DET
# notes note NOUN
# de de ADP
# la le DET
# traductrice traductrice NOUN
# Ada Ada PROPN
# Augusta Augusta PROPN
# , , PUNCT
# comtesse comtesse VERB
# de de ADP
# Lovelace Lovelace PROPN
# , , PUNCT
# publié publier VERB
# dans dans ADP
# Scientific Scientific PROPN
# Memoirs Memoirs PROPN
# , , PUNCT
# vol vol NOUN
# . . PUNCT
# 3 3 NUM
# ( ( PUNCT
# 1842 1842 NUM
# ) ) PUNCT
#
#
#
#
#
#
#  SPACE
# = = AUX
# = = AUX
# = = X
# = = PRON
# Bases Bases PROPN
# de de ADP
# données donnée NOUN
# et et CCONJ
# dictionnaires dictionnaire NOUN
# = = AUX
# = = X
# = = X
# = = VERB
#
#
#
#
#  SPACE
# Ressources ressource NOUN
# relatives relatif ADJ
# aux à ADP
# beaux beau NOUN
# - - NOUN
# arts art NOUN
# : : PUNCT
# ( ( PUNCT
# en en X
# ) ) PUNCT
# British British PROPN
# Museum Museum PROPN
# ( ( PUNCT
# en en NOUN
# ) ) PUNCT
# National national NOUN
# Portrait portrait NOUN
# Gallery Gallery PROPN
#
#
#  SPACE
# Ressource Ressource PROPN
# relative relatif ADJ
# à à ADP
# la le DET
# littérature littérature NOUN
# : : PUNCT
# ( ( PUNCT
# en en X
# ) ) PUNCT
# The The X
# Encyclopedia Encyclopedia PROPN
# of of ADP
# Science Science PROPN
# Fiction fiction NOUN
#
#
#  SPACE
# Ressource Ressource PROPN
# relative relatif ADJ
# à à ADP
# la le DET
# bande bande NOUN
# dessinée dessiner VERB
# : : PUNCT
# ( ( PUNCT
# en en X
# ) ) PUNCT
# Comic Comic PROPN
# Vine vin ADJ
#
#
#
#
#   SPACE
# Portail portail NOUN
# des de ADP
# mathématiques mathématique NOUN
#       SPACE
# Portail portail NOUN
# des de ADP
# femmes femme NOUN
# et et CCONJ
# du de ADP
# féminisme féminisme NOUN
#       SPACE
# Portail portail NOUN
# du de ADP
# XIXe xix ADJ
# siècle siècle NOUN
#       SPACE
# Portail portail NOUN
# de de ADP
# la le DET
# programmation programmation NOUN
# informatique informatique ADJ
#       SPACE
# Portail portail NOUN
# du de ADP
# Royaume Royaume PROPN
# - - PROPN
# Uni Uni PROPN
#       SPACE
# Portail portail NOUN
# de de ADP
# l’ l’ ADJ
# histoire histoire NOUN
# des de ADP
# sciences science NOUN

# %% [markdown]
# #### Pandas
#
# You can use Pandas to better visualize the results

# %%
# Using pandas for a better visualization 
import pandas as pd

spacy_pos_tagged = [(w, w.lemma_, w.tag_, w.pos_) for w in doc]
pd.DataFrame(spacy_pos_tagged,
             columns=['Word', 'Lemma', 'POS tag', 'Tag type'])
# Out:
#           Word     Lemma POS tag Tag type
# 0          Ada       Ada   PROPN    PROPN
# 1     Lovelace  Lovelace   PROPN    PROPN
# 2            ,         ,   PUNCT    PUNCT
# 3           de        de     ADP      ADP
# 4          son       son     DET      DET
# ...        ...       ...     ...      ...
# 3204        de        de     ADP      ADP
# 3205        l’        l’     ADJ      ADJ
# 3206  histoire  histoire    NOUN     NOUN
# 3207       des        de     ADP      ADP
# 3208  sciences   science    NOUN     NOUN
#
# [3209 rows x 4 columns]

# %% [markdown]
# #### Look at the results:
# * lemmatization:
#   * ambiant ambier VERB

# %% [markdown]
# #### Notes on POS tags:
#
# * You can use the method 'explain' to have information about some annotation, for example the POS tags, see the code below.
# * Here we used a very small set of POS (vs e.g. 36 in the PTB: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html)

# %%
# Inspect POS tags
all_tags = set()
for token in doc:
  all_tags.add(token.pos_)
for tag in all_tags:
  print( tag, spacy.explain(tag)) # explain each label
# Out:
# ADJ adjective
# PUNCT punctuation
# PRON pronoun
# NOUN noun
# VERB verb
# SPACE space
# ADV adverb
# AUX auxiliary
# DET determiner
# SCONJ subordinating conjunction
# X other
# PROPN proper noun
# ADP adposition
# NUM numeral
# CCONJ coordinating conjunction

# %% [markdown]
# ## 5- Named entity recognition
#
# As part of the preprocessing pipeline, Spacy has also carried out named entity recognition.
#
# **Exercise 8:**
# * print out each named entity, together with the label assigned to it
# * what do the labels stand for?
# * Use the module called 'displacy' to visualize the Named Entities directly in the text.

# %%
entity_labels = set()
for entity in doc.ents:
  label = entity.label_
  print( entity.text, '\t', label )
  entity_labels.add( label )
# Out:
# Ada Lovelace 	 PER
# Augusta 	 MISC
# comtesse de 	 LOC
# Ada Byron 	 PER
# Londres 	 LOC
# Marylebone 	 LOC
# Charles Babbage 	 PER
# Ada Lovelace 	 PER
# Babbage 	 LOC
# Allemagne 	 LOC
# France 	 LOC
# Ada 	 MISC
# Ada 	 MISC
# George Gordon 	 PER
# Annabella 	 PER
# Caroline Lamb 	 PER
# Byron 	 PER
# Ada 	 MISC
# Augusta 	 MISC
# Augusta Leigh 	 PER
# Byron 	 PER
# Ada 	 MISC
# Byron 	 PER
# Augusta 	 PER
# Byron 	 PER
# Annabella 	 PER
# Ada 	 MISC
# Byron 	 PER
# Annabella 	 PER
# Byron 	 PER
# Ada 	 MISC
# Byron 	 PER
# Royaume-Uni 	 LOC
# Annabella 	 PER
# Byron 	 PER
# Annabella 	 PER
# Ada 	 MISC
# Ada 	 MISC
# Mary Somerville 	 PER
# XIXe 	 MISC
# Mary 	 PER
# Charles Babbage 	 PER
# Ada 	 MISC
# Ada 	 MISC
# Babbage 	 LOC
# David Brewster 	 PER
# Charles Wheatstone 	 PER
# Charles Dickens 	 PER
# Michael Faraday 	 PER
# William King 	 PER
# Byron 	 PER
# Annabella 	 PER
# Anne Blunt 	 PER
# Ralph Gordon 	 PER
# William 	 PER
# Ada 	 MISC
# Ada 	 MISC
# Ockham Park 	 LOC
# Okham 	 LOC
# Augusta Ada 	 MISC
# Lovelace 	 LOC
# Ada Lovelace 	 PER
# Lady Lovelace 	 PER
# Ada 	 MISC
# Babbage 	 PER
# Auguste De Morgan 	 PER
# Ada 	 MISC
# De Morgan 	 PER
# Ada 	 MISC
# Ada 	 MISC
# De Morgan 	 PER
# Ada 	 MISC
# Nature 	 MISC
# Ada 	 MISC
# Babbage 	 LOC
# Mémoire sur la machine 	 MISC
# Babbage 	 LOC
# Babbage 	 LOC
# Louis-Frédéric Ménabréa 	 PER
# Charles Wheatstone 	 PER
# Ada Lovelace 	 PER
# Scientific Memoirs 	 MISC
# Babbage 	 PER
# Ada 	 MISC
# Babbage 	 PER
# Ada 	 MISC
# Ada 	 MISC
# Charles Babbage 	 PER
# Ada 	 MISC
# A 	 LOC
# G 	 LOC
# G 	 PER
# Bernoulli 	 PER
# Catherine Dufour 	 PER
# Babbage 	 PER
# Jacquard 	 PER
# Ada Lovelace 	 PER
# Babbage 	 LOC
# Ada 	 MISC
# Bernoulli 	 PER
# Babbage 	 LOC
# Ada 	 MISC
# Betty Toole 	 PER
# Ada 	 MISC
# Babbage 	 LOC
# Ada 	 MISC
# Babbage 	 LOC
# Bruce Collier 	 PER
# Babbage 	 LOC
# Babbage 	 PER
# Ada Lovelace 	 PER
# Stephen Wolfram 	 PER
# Babbage 	 LOC
# Bernoulli 	 PER
# Notations of the Analytical 	 MISC
# Babbage 	 LOC
# Ada Lovelace 	 PER
# Babbage 	 LOC
# Ada Lovelace 	 PER
# Doron Swade 	 PER
# Babbage 	 LOC
# Ada Lovelace 	 PER
# Ada 	 MISC
# Doron Swade 	 PER
# Machine 	 PER
# La Machine peut arranger 	 MISC
# Alan Turing 	 PER
# Ruine 	 LOC
# Babbage 	 LOC
# Lady Lovelace 	 PER
# paris 	 LOC
# Epsom 	 PER
# Anne Blunt 	 PER
# Moyen-Orient 	 LOC
# Hucknall 	 LOC
# Newstead Abbey 	 ORG
# comté de Nottingham 	 LOC
# Notoriété 	 LOC
# Ada Lovelace 	 PER
# Ada 	 MISC
# département de la Défense américain 	 LOC
# CII 	 ORG
# Honeywell Bull 	 PER
# Français 	 LOC
# Jean Ichbiah 	 PER
# Ada 	 MISC
# Jack Cooper 	 PER
# Naval Material Command 	 MISC
# Ada Lovelace 	 PER
# Microsoft 	 ORG
# Nvidia 	 ORG
# Ada Lovelace 	 PER
# RTX 	 MISC
# (232923) 	 LOC
# Adalovelace 	 PER
# Ada 	 MISC
# La Machine à différences 	 MISC
# Bruce Sterling 	 PER
# William Gibson 	 PER
# Babbage 	 LOC
# Conceiving Ada 	 MISC
# Lynn Hershman Leeson 	 PER
# Britannique 	 LOC
# Ada Lovelace 	 PER
# Tilda Swinton 	 PER
# Ada 	 MISC
# Egger 	 PER
# Thierry Smolderen 	 PER
# Ada Lovelace 	 PER
# Ada 	 MISC
# Vincent Dutreuil 	 PER
# François Maingoval 	 PER
# Ada Lovelace 	 PER
# machine Enigma 	 MISC
# Ada Byron 	 PER
# IRA 	 ORG
# Institut régional d'administration) de Lille 	 LOC
# ADA 	 MISC
# Jehuty 	 LOC
# Zone of the Enders 	 MISC
# ADA 	 MISC
# Lady 	 MISC
# Ada Lovelace 	 PER
# Castle Falkenstein 	 PER
# Mike Pondsmith 	 PER
# Lovelace 	 LOC
# Lovey 	 LOC
# L'Espace d'un an, 	 MISC
# Becky 	 LOC
# Ada Lovelace 	 PER
# Ada Gordon 	 PER
# Doctor Who 	 PER
# La Chute des espions 	 MISC
# Docteur 	 LOC
# Maître.
#  	 ORG
# Arena 13 	 MISC
# Joseph Delaney 	 PER
# Victoria 	 MISC
# Emerald Fennell 	 PER
# Notes 	 LOC
# Annexes 	 LOC
# Benjamin Woolley 	 PER
# The Bride of Science: Romance 	 ORG
# Reason, and Byron's Daughter 	 MISC
# McGraw-Hill 	 LOC
# Dorothy Stein 	 PER
# Ada: A Life and a Legacy 	 MISC
# Cambridge 	 LOC
# The MIT Press 	 ORG
# ISBN 	 ORG
# Doron Swade 	 PER
# The Difference Engine 	 MISC
# Charles Babbage and the Quest to Build the First Computer 	 PER
# Penguin 	 LOC
# Non-Classics 	 LOC
# Bruce Collier 	 PER
# Charles Babbage and the Engines of Perfection 	 PER
# Oxford University Press 	 ORG
# Betty Toole 	 PER
# Ada and the 	 ORG
# Scientific American 	 MISC
# Stephen Wolfram 	 PER
# Untangling the Tale of Ada Lovelace 	 MISC
# Jean-Paul Soyer 	 PER
# Ada de Lovelace 	 PER
# Sorbier 	 LOC
# Paris 	 LOC
# ISBN 2-7320-3539-4 	 MISC
# Dorothy Stein 	 PER
# Ada Byron 	 PER
# Ada Byron 	 PER
# a life and 	 MISC
# Maurice Gabail 	 PER
# Seghers 	 LOC
# Paris 	 LOC
# ISBN 2-232-10145-2 	 MISC
# Betty Alexandra Toole 	 PER
# Ada 	 MISC
# the enchantress of numbers, prophet of the computer 	 MISC
# a pathway 	 MISC
# Strawberry Press 	 PER
# Mill Valley 	 PER
# ISBN 	 ORG
# Catherine Dufour 	 PER
# Ada 	 MISC
# Librairie Arthème Fayard 	 PER
# ISBN 2-213-71279-4 	 MISC
# Jean-Luc Dousset 	 PER
# Ada 	 MISC
# Byron 	 PER
# Jeanne d'Arc 	 PER
# Articles 	 PER
# Histoire de l'informatique
# Ada 	 MISC
# Ada 	 MISC
# Famille Byron 	 ORG
# Prénom 	 LOC
# ADA 	 MISC
# La Conversation scientifique 	 MISC
# France Culture 	 ORG
# Ada Lovelace 	 PER
# La Méthode 	 MISC
# France Culture 	 ORG
# Sketch of the Analytical Engine 	 MISC
# Charles Babbage 	 PER
# Esq 	 LOC
# Ada Augusta 	 PER
# Scientific Memoirs, vol. 	 MISC
# Bases 	 LOC
# Ressources 	 LOC
# British Museum 	 LOC
# National Portrait Gallery 	 MISC
# The Encyclopedia of Science Fiction 	 MISC
# Comic Vine
#
#  Portail des mathématiques 	 PER
# Portail 	 LOC
# Portail du XIXe 	 MISC
# Portail 	 LOC
# Portail du Royaume-Uni    	 MISC
#
#
# ORG Companies, agencies, institutions, etc.
# MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
# PER Named person or family.
# LOC Non-GPE locations, mountain ranges, bodies of water

# %%
for l in entity_labels:
  print( l, spacy.explain(l))
# Out:
# ORG Companies, agencies, institutions, etc.
# MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
# PER Named person or family.
# LOC Non-GPE locations, mountain ranges, bodies of water

# %% [markdown]
# #### Visualization
#
# A module called 'displacy' can be used to visualize the Named Entities directly in the text.

# %%
from spacy import displacy

# Visually
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada Lovelace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , de son nom complet
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Augusta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Ada King,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     comtesse de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  Lovelace, née
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  le 10 décembre 1815 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Londres
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et morte le 27 novembre 1852 à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marylebone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  dans la même ville, est une pionnière de la science informatique.</br>Elle est principalement connue pour avoir réalisé le premier véritable programme informatique, lors de son travail sur un ancêtre de l'ordinateur : la machine analytique de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charles Babbage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Dans ses notes, on trouve en effet le premier programme publié, destiné à être exécuté par une machine, ce qui fait d'
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada Lovelace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  « le premier programmeur du monde ». Elle a également entrevu et décrit certaines possibilités offertes par les calculateurs universels, allant bien au-delà du calcul numérique et de ce qu'imaginaient
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Babbage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et ses contemporains,.</br>Elle est assez connue dans les pays anglo-saxons et en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Allemagne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , notamment dans les milieux féministes ; elle est moins connue en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , mais de nombreux développeurs connaissent le langage
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , nommé en son honneur. </br></br></br>== Biographie ==</br></br></br>=== Environnement familial ===</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  était la seule fille légitime du poète
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     George Gordon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Byron et de son épouse
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Annabella
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Milbanke, une femme intelligente et cultivée, cousine de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Caroline Lamb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , dont la liaison avec
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  fut à l'origine d'un scandale. Le premier prénom d'
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Augusta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , aurait été choisi en hommage à
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Augusta Leigh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , la demi-sœur de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Byron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , avec qui ce dernier aurait eu des relations incestueuses. Le prénom
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ada
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mar

# %% [markdown]
# Note on Named Entity Recognition
# * "Church" = organization instead or person
# * Pitts' 1943: person + date = ORG, not well segmented

# %% [markdown]
# ## 6- Parsing
#
# Finally, as part of the pipeline, Spacy has also performed a dependency parsing (note that each module can de disabled if not needed).
#
# **Exercise 9:** Extract all Noun Phrases from the file
#
# * Retrieve the information from the dependency parses: dependent and head of each token
# * Use displacy to visualize a parse tree: first try with a simple sentence (e.g. *La petite brise la glace.*) then use the first sentence of the document.
# * Navigating the parse tree. Each element of the tree is associated to attributes: you can use them to inspect the different elements of the trees:
#   * Define a Panda dataframe with each token id associated to its head, with the relation between them. The eventual children of the current token are also printed.
# * Print all the adjectives and the noun they modify

# %%
# Load the model
#nlp = spacy.load('fr_core_news_sm')

doc_ada_fr = nlp(content_fr)

sentence = next(doc_ada_fr.sents)

for token in sentence:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.head)
# Out:
# Ada Ada PROPN PROPN ROOT Ada
# Lovelace Lovelace PROPN PROPN flat:name Ada
# , , PUNCT PUNCT punct Ada
# de de ADP ADP case nom
# son son DET DET det nom
# nom nom NOUN NOUN nmod Ada
# complet complet ADJ ADJ amod nom
# Augusta Augusta PROPN PROPN nmod nom

# %%
# Load the model
#nlp = spacy.load('fr_core_news_sm')
text = 'La petite brise la glace.'

doc_toy = nlp(text)

# Visualization
displacy.render(doc_toy, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="28729d26cc39480d9bdcff953294a6ac-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">petite</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">brise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">glace.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28729d26cc39480d9bdcff953294a6ac-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28729d26cc39480d9bdcff953294a6ac-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28729d26cc39480d9bdcff953294a6ac-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28729d26cc39480d9bdcff953294a6ac-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28729d26cc39480d9bdcff953294a6ac-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28729d26cc39480d9bdcff953294a6ac-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-28729d26cc39480d9bdcff953294a6ac-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-28729d26cc39480d9bdcff953294a6ac-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Print the next sentence of our document
sentence0 = next(doc_ada_fr.sents)
print(sentence0)


# Visualization
displacy.render(sentence0, style="dep", jupyter=True)
# Out:
# Ada Lovelace, de son nom complet Augusta
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="ed4f053029e94d96b9210767cd3dbb70-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ada</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Lovelace,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">son</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">nom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">complet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Augusta</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed4f053029e94d96b9210767cd3dbb70-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed4f053029e94d96b9210767cd3dbb70-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed4f053029e94d96b9210767cd3dbb70-0-1" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed4f053029e94d96b9210767cd3dbb70-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed4f053029e94d96b9210767cd3dbb70-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed4f053029e94d96b9210767cd3dbb70-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed4f053029e94d96b9210767cd3dbb70-0-3" stroke-width="2px" d="M70,264.5 C70,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed4f053029e94d96b9210767cd3dbb70-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed4f053029e94d96b9210767cd3dbb70-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed4f053029e94d96b9210767cd3dbb70-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ed4f053029e94d96b9210767cd3dbb70-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ed4f053029e94d96b9210767cd3dbb70-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# #### Navigating the parse tree

# %%
# Navigating the parse tree
spacy_dep_rel = [(w.text, w.pos_, w.dep_, w.head.text, w.head.pos_, [";".join([str(child.idx),child.text]) for child in w.children]) for w in sentence0]
pd.DataFrame(spacy_dep_rel,
             columns=['Word', 'Pos', 'Dep', 'Head text', 'Head pos', 'children'])
# Out:
#        Word    Pos        Dep Head text Head pos  \
# 0       Ada  PROPN       ROOT       Ada    PROPN
# 1  Lovelace  PROPN  flat:name       Ada    PROPN
# 2         ,  PUNCT      punct       Ada    PROPN
# 3        de    ADP       case       nom     NOUN
# 4       son    DET        det       nom     NOUN
# 5       nom   NOUN       nmod       Ada    PROPN
# 6   complet    ADJ       amod       nom     NOUN
# 7   Augusta  PROPN       nmod       nom     NOUN
#
#                                   children
# 0               [4;Lovelace, 12;,, 21;nom]
# 1                                       []
# 2                                       []
# 3                                       []
# 4                                       []
# 5  [14;de, 17;son, 25;complet, 33;Augusta]
# 6                                       []
# 7                                       []

# %%
for sent in doc_ada_fr.sents:
  for w in sent:
    if w.pos_ == 'ADJ':
      print( w.text, w.head.text, w.head.pos_) # pas que des Noms, révèle des erreurs de POS tagging
# Out:
# complet nom NOUN
# même ville NOUN
# informatique science NOUN
# premier programme NOUN
# véritable programme NOUN
# informatique programme NOUN
# analytique machine NOUN
# premier programme NOUN
# premier programmeur NOUN
# offertes possibilités NOUN
# universels calculateurs NOUN
# numérique calcul NOUN
# féministes milieux NOUN
# nombreux développeurs NOUN
# familial Environnement NOUN
# seule fille NOUN
# légitime fille NOUN
# poète fille NOUN
# intelligente femme NOUN
# premier prénom NOUN
# dernier eu VERB
# incestueuses relations NOUN
# court « VERB
# ancien « VERB
# vocalique ancien ADJ
# même année NOUN
# quitte Annabella PROPN
# « appelait VERB
# jeune fille NOUN
# éminente chercheuse ADJ
# chercheuse , PUNCT
# scientifique autrice NOUN
# XIXe siècle NOUN
# — Ada PROPN
# âgée Ada PROPN
# proches deviennent VERB
# autres connaissances NOUN
# 1er marie VERB
# dévoué dévoué ADJ
# complet nom NOUN
# grande partie NOUN
# honorable honorable ADJ
# fragile santé NOUN
# mathématiques activités NOUN
# enthousiaste élève NOUN
# créative enthousiaste ADJ
# positifs retours NOUN
# combinaison singulière NOUN
# mentionne mentionne ADJ
# inépuisable énergie NOUN
# insatiable inépuisable ADJ
# » mentionne ADJ
# nouveau de ADP
# analytique machine NOUN
# dernier propose VERB
# suisse journal NOUN
# analytique machine NOUN
# italien mathématicien NOUN
# bon niveau NOUN
# spécialisé journal NOUN
# scientifiques articles NOUN
# étrangers articles NOUN
# malade intervient VERB
# même période NOUN
# analytique machine NOUN
# frénétique travail NOUN
# original article NOUN
# véritable algorithme NOUN
# premier programme NOUN
# véritable programme NOUN
# informatique programme NOUN
# première boucle NOUN
# conditionnelle boucle NOUN
# véritable concept NOUN
# informatique concept NOUN
# séquentiels programmes NOUN
# constante relation NOUN
# sûr semble VERB
# limité indiquer VERB
# formules mathématiques NOUN
# spécialistes meilleurs NOUN
# sévère jugement NOUN
# suivant jugement NOUN
# légère exagération NOUN
# propres raisons NOUN
# propres retrouvé VERB
# possibles calculs NOUN
# analytique machine NOUN
# tous datés NOUN
# simple supervision NOUN
# bienveillante supervision NOUN
# autres notes NOUN
# considère potentialités NOUN
# « visionnaire NOUN
# moderne perspective NOUN
# numérique calcul NOUN
# algébrique calcul NOUN
# autre type NOUN
# spécifique machine NOUN
# algébriques calculs NOUN
# mathématique contexte NOUN
# scientifique manière NOUN
# degré longueur NOUN
# » hypothèse NOUN
# autre passage NOUN
# numérique forme NOUN
# arithmétique forcément VERB
# numérique arithmétique ADJ
# algébrique plutôt ADV
# analytique algébrique ADJ
# numériques quantités NOUN
# autre symbole NOUN
# général symbole NOUN
# algébrique notation NOUN
# appropriées conventions NOUN
# telle notion NOUN
# universel calculateur NOUN
# généraux symboles NOUN
# numérique calculatrice NOUN
# britannique gouvernement NOUN
# souffrances horribles NOUN
# dernière Anne ADJ
# Anne connue VERB
# élevé voyagé VERB
# informatique avènement NOUN
# américain Défense NOUN
# informatique historiens NOUN
# première personne NOUN
# Microsoft produits NOUN
# nouvelle architecture NOUN
# graphique architecture NOUN
# nouvelle série NOUN
# graphiques cartes NOUN
# principaux personnages NOUN
# alternative histoire NOUN
# industrielle manière NOUN
# informatique ère NOUN
# petite fille NOUN
# jeune fille NOUN
# libre fille NOUN
# indépendante libre ADJ
# homonyme série NOUN
# 37e promotion NOUN
# chargés attachés NOUN
# régional Institut PROPN
# artificielle intelligence NOUN
# synthétique voix NOUN
# féminine tessiture NOUN
# expert personnage NOUN
# steampunk rôle NOUN
# artificielle intelligence NOUN
# entière part NOUN
# jeune fille NOUN
# diverses époques NOUN
# mondiale crise NOUN
# programmeuse présentée VERB
# principaux personnages NOUN
# informatique programmation NOUN
# informatique pionnière NOUN
# premier programme NOUN
# informatique programme NOUN
# connexes Articles PROPN
# informatique Histoire NOUN
# premières femmes NOUN
# externes Liens NOUN
# scientifique Conversation NOUN
# grande ordinatrice NOUN
# scientifique Méthode PROPN
# relatives Ressources NOUN
# relative Ressource PROPN
# relative Ressource PROPN
# Vine Comic PROPN
# XIXe siècle NOUN
# informatique programmation NOUN
# l’ histoire NOUN

# %%
for sent in doc_ada_fr.sents:
  for w in sent:
    if w.pos_ == 'ADJ' and w.head.pos_ == 'NOUN':
      print( w.text, w.head.text, w.head.pos_) # pas que des Noms, révèle des erreurs de POS tagging
# Out:
# complet nom NOUN
# même ville NOUN
# informatique science NOUN
# premier programme NOUN
# véritable programme NOUN
# informatique programme NOUN
# analytique machine NOUN
# premier programme NOUN
# premier programmeur NOUN
# offertes possibilités NOUN
# universels calculateurs NOUN
# numérique calcul NOUN
# féministes milieux NOUN
# nombreux développeurs NOUN
# familial Environnement NOUN
# seule fille NOUN
# légitime fille NOUN
# poète fille NOUN
# intelligente femme NOUN
# premier prénom NOUN
# incestueuses relations NOUN
# même année NOUN
# jeune fille NOUN
# scientifique autrice NOUN
# XIXe siècle NOUN
# autres connaissances NOUN
# complet nom NOUN
# grande partie NOUN
# fragile santé NOUN
# mathématiques activités NOUN
# enthousiaste élève NOUN
# positifs retours NOUN
# combinaison singulière NOUN
# inépuisable énergie NOUN
# analytique machine NOUN
# suisse journal NOUN
# analytique machine NOUN
# italien mathématicien NOUN
# bon niveau NOUN
# spécialisé journal NOUN
# scientifiques articles NOUN
# étrangers articles NOUN
# même période NOUN
# analytique machine NOUN
# frénétique travail NOUN
# original article NOUN
# véritable algorithme NOUN
# premier programme NOUN
# véritable programme NOUN
# informatique programme NOUN
# première boucle NOUN
# conditionnelle boucle NOUN
# véritable concept NOUN
# informatique concept NOUN
# séquentiels programmes NOUN
# constante relation NOUN
# formules mathématiques NOUN
# spécialistes meilleurs NOUN
# sévère jugement NOUN
# suivant jugement NOUN
# légère exagération NOUN
# propres raisons NOUN
# possibles calculs NOUN
# analytique machine NOUN
# tous datés NOUN
# simple supervision NOUN
# bienveillante supervision NOUN
# autres notes NOUN
# considère potentialités NOUN
# « visionnaire NOUN
# moderne perspective NOUN
# numérique calcul NOUN
# algébrique calcul NOUN
# autre type NOUN
# spécifique machine NOUN
# algébriques calculs NOUN
# mathématique contexte NOUN
# scientifique manière NOUN
# degré longueur NOUN
# » hypothèse NOUN
# autre passage NOUN
# numérique forme NOUN
# numériques quantités NOUN
# autre symbole NOUN
# général symbole NOUN
# algébrique notation NOUN
# appropriées conventions NOUN
# telle notion NOUN
# universel calculateur NOUN
# généraux symboles NOUN
# numérique calculatrice NOUN
# britannique gouvernement NOUN
# souffrances horribles NOUN
# informatique avènement NOUN
# américain Défense NOUN
# informatique historiens NOUN
# première personne NOUN
# Microsoft produits NOUN
# nouvelle architecture NOUN
# graphique architecture NOUN
# nouvelle série NOUN
# graphiques cartes NOUN
# principaux personnages NOUN
# alternative histoire NOUN
# industrielle manière NOUN
# informatique ère NOUN
# petite fille NOUN
# jeune fille NOUN
# libre fille NOUN
# homonyme série NOUN
# 37e promotion NOUN
# chargés attachés NOUN
# artificielle intelligence NOUN
# synthétique voix NOUN
# féminine tessiture NOUN
# expert personnage NOUN
# steampunk rôle NOUN
# artificielle intelligence NOUN
# entière part NOUN
# jeune fille NOUN
# diverses époques NOUN
# mondiale crise NOUN
# principaux personnages NOUN
# informatique programmation NOUN
# informatique pionnière NOUN
# premier programme NOUN
# informatique programme NOUN
# informatique Histoire NOUN
# premières femmes NOUN
# externes Liens NOUN
# scientifique Conversation NOUN
# grande ordinatrice NOUN
# relatives Ressources NOUN
# XIXe siècle NOUN
# informatique programmation NOUN
# l’ histoire NOUN

# %%
## TO REMOVE
import spacy
import spacy.cli
from spacy import displacy
from spacy.matcher import DependencyMatcher
spacy.cli.download("fr_core_news_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %% [markdown]
# ## 7- Putting it all together
#
# Now we are going to use the skills practiced in the preceding exercises to build a simple question-answering system on a toy dataset (in French).
#
# We will focus on specific questions of the form "Qui a peint X ?".
# We will define patterns based on differents ways of formulating this question, and use them to extract the answer from a small toy corpus based on wikipedia pages on paintings.
#
# When you're done with this exercise, try to answer other types of questions, such as "Où est exposé X ?", "Quand a été peinte X ?".
#
# Below, we reload the spacy French model adding specific options to merge named entities containing multiple tokens.

# %%
# Load the model
nlp = spacy.load('fr_core_news_sm')

nlp.add_pipe("merge_entities")
nlp.add_pipe("merge_noun_chunks")
# Out:
# <function spacy.pipeline.functions.merge_noun_chunks(doc: spacy.tokens.doc.Doc) -> spacy.tokens.doc.Doc>

# %% [markdown]
# Here is the list of questions we will consider.
# You also need a corpus of source document, you can find it on Moodle (corpus_qa.txt).

# %%
question_list = [
    'La Joconde est un tableau de qui ?',
    'Le radeau de la méduse est une peinture réalisée par qui ?'
]
corpus = 'corpus_qa.txt'

# %% [markdown]
# **Exercise 10:** In this part, we focus on the first question. This question is designed to be similar to the document containing the answer. We can thus define a pattern based on its structure to extract the answer from the document.
#
# - Process the question using the spacy nlp pipeline
# - display its parse tree and / or print a Pandas dataframe containing information from the parse tree
# - Now to define a lexico-syntactic pattern, you are going to use spacy *DependencyMatcher* : https://spacy.io/usage/rule-based-matching#dependencymatcher
#   * Look at the doc to understand how it works
#   * Define a pattern that should match 'qui ' in the question

# %%
# Display the parse tree of the first question 
q1 = question_list[0]
q1_prep = nlp(q1)
displacy.render(q1_prep, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="8f36a1af27e04fdfae1308079417172e-0" class="displacy" width="1100" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">La Joconde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">tableau</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">qui ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f36a1af27e04fdfae1308079417172e-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f36a1af27e04fdfae1308079417172e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f36a1af27e04fdfae1308079417172e-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f36a1af27e04fdfae1308079417172e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f36a1af27e04fdfae1308079417172e-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f36a1af27e04fdfae1308079417172e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f36a1af27e04fdfae1308079417172e-0-3" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f36a1af27e04fdfae1308079417172e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f36a1af27e04fdfae1308079417172e-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f36a1af27e04fdfae1308079417172e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
from spacy.matcher import DependencyMatcher
# Define a lexico-syntactic pattern that allows to retrieve the answer

pattern_tableau = [
    {
        "RIGHT_ID": "tableau",
        "RIGHT_ATTRS": {"ORTH": "tableau"}
    },

    {
        "LEFT_ID": "tableau",
        "REL_OP": ">",
        "RIGHT_ID": "mod",
        "RIGHT_ATTRS": {"DEP": "nmod"},
    },

]

# If you match the pattern to the original question, it should output 'qui'

matcher = DependencyMatcher(nlp.vocab)
matcher.add("tableau", [pattern_tableau])

matches = matcher(q1_prep)

print(matches) # [(4851363122962674176, [6, 0, 10, 9])]
# Each token_id corresponds to one pattern dict
match_id, token_ids = matches[0]

for i in range(len(token_ids)):
  if pattern_tableau[i]["RIGHT_ID"] == 'mod':
    print(q1_prep[token_ids[i]].text)
# Out:
# [(2044181489145587150, [3, 5])]
# qui

# %% [markdown]
# **Exercise 11**: Retrieve matching documents
# Retrieve the documents that are relevant to the question, i.e. the ones containing the keyword 'La Joconde'.
#
# It is recommended to define a function, that could be used for the next exercises. It could work by:
#
# * first indexing all the documents using the named entities present in the document (i.e. build a dictionnary mapping a named entity to all documents where it is present)
# * now the *retrieve_documents(...)* method should try to match the input keywork with a named entity and return the matching documents.
# * Test the function with 'Joconde':
#   * Does it work with the method based on named entities?
#   * Add a backup solution : if no document is found,simply try to find the string corresponding to the keyword in the document

# %%
# Retrieve the document that is relevant to the question, i.e. the one 
# containing 'La Joconde'
# Indexation of the documents based on named entities 
# + if no NE found, simple pattern matching


# Add a lowercasing ?
def index_corpus( documents_prep ):
  index = {}
  # indexation on named entities
  for i, doc in enumerate(documents_prep):
    entities = doc.ents
    for ent in doc.ents:
      if ent in index:
        index[ent].append(i)
      else:
        index[ent]=[i]
  return index 

def retrieve_documents(documents_prep, index, keyword):
  matching_docs = []
  for e in index.keys():
    if keyword in e.text: # match Joconde in La Joconde
      matching_docs.extend(index[e])
  if len(matching_docs) == 0: # solution de repli
    for i, doc in enumerate(documents_prep):
      for tok in doc:
        if keyword in tok.text:
          matching_docs.append(i)
  return matching_docs


with open(corpus) as infile:
  documents = infile.read().split('\n\n')
documents_prep = [nlp(doc) for doc in documents]
index = index_corpus( documents_prep )

matching_docs = retrieve_documents(documents_prep, index, 'Joconde')
print(matching_docs)
# Out:
# [0]

# %% [markdown]
# **Exercise 12:** Test the pattern
#
# - Apply the pattern to each sentence of the retrieved document, do you find the right answer?

# %%
#  Apply the pattern to each sentence of this document, do you find the right answer?
# --> you should define a more general function that goes through all the matched
# documents (but here toy dataset, only one doc per question)

id_doc = matching_docs[0]
answers = []
for sent in documents_prep[id_doc].sents:
  matches = matcher(sent)

  for match_id, tok_id in matches:
    for idx,i in enumerate(tok_id[:]):
      pattern_part = pattern_tableau[idx]
      text = sent[i].text
      if pattern_part["RIGHT_ID"]=="mod":
          answers.append(text)

print("Réponses possibles: ")
print("-"+"\n-".join(answers))
# Out:
# Réponses possibles:
# -Léonard de Vinci

# %% [markdown]
# **Exercise 13:** Now define a pattern to answer the second question, and find the answer!
#
# Be careful, there is a little issue here:
# - Display the parse tree for the question and the matching document: what do you observe?
# - Build a pattern to match the question and the answer (Hint : you can use a list of dependency relations in the pattern, using e.g. *"RIGHT_ATTRS": {"DEP": {"IN":[ "acl", "advcl" ] }*
# - Finally, retrieve the answer

# %%
# Display the parse tree of the second question 
q2 = question_list[1]
q2_prep = nlp(q2)
displacy.render(q2_prep, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="5084b5e0b5fd4ca4aa1d518663925bea-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Le radeau</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">la méduse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">une</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">peinture</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">réalisée</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">par</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">qui ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 925.0,2.0 925.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-2" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,266.5 L403.0,254.5 387.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-3" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-5" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1090.0,266.5 L1098.0,254.5 1082.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-7" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5084b5e0b5fd4ca4aa1d518663925bea-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl:agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,266.5 L1453.0,254.5 1437.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
# Display the parse tree of the matching document (first and unique sentence)
matching_docs = retrieve_documents(documents_prep, index, 'Méduse')
id_doc = matching_docs[0]
sentences = documents_prep[id_doc].sents
displacy.render(list(sentences)[0], style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="7897c231f4874d8b95cbc5edaf928b03-0" class="displacy" width="2675" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Le Radeau de La Méduse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">une</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">peinture</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">à</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">l'huile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">sur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">toile,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">réalisée</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">entre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">1818</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">1819</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">par</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Théodore Géricault.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7897c231f4874d8b95cbc5edaf928b03-0-0" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7897c231f4874d8b95cbc5edaf928b03-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7897c231f4874d8b95cbc5edaf928b03-0-1" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7897c231f4874d8b95cbc5edaf928b03-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7897c231f4874d8b95cbc5edaf928b03-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7897c231f4874d8b95cbc5edaf928b03-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7897c231f4874d8b95cbc5edaf928b03-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7897c231f4874d8b95cbc5edaf928b03-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7897c231f4874d8b95cbc5edaf928b03-0-4" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7897c231f4874d8b95cbc5edaf928b03-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl:mod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7897c231f4874d8b95cbc5edaf928b03-0-5" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7897c231f4874d8b95cbc5edaf928b03-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7897c231f4874d8b95cbc5edaf928b03-0-6" stroke-width="2px" d="M595,352.0 C595,89.5 1270.0,89.5 1270.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7897c231f4874d8b95cbc5edaf928b03-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="midd

# %%
# Define a pattern that matches both the question and answer
# here we have a slight difference between the dep rel label for quest and answer
from spacy.matcher import DependencyMatcher
pattern_peinture = [
    {
        "RIGHT_ID": "peinture",
        "RIGHT_ATTRS": {"ORTH": "peinture"}
    },
    {
        "LEFT_ID": "peinture",
        "REL_OP": ">",
        "RIGHT_ID": "realise",
        "RIGHT_ATTRS": {"DEP": {"IN":[ "acl", "advcl" ] }},
    },


    {
        "LEFT_ID": "realise",
        "REL_OP": ">",
        "RIGHT_ID": "agent",
        "RIGHT_ATTRS": {"DEP": "obl:agent"},
    },

]

# If you match the pattern to the original question, it should output 'qui'

matcher = DependencyMatcher(nlp.vocab)
matcher.add("peinture", [pattern_peinture])

matches = matcher(q2_prep)

print(matches) # [(4851363122962674176, [6, 0, 10, 9])]
# Each token_id corresponds to one pattern dict
match_id, token_ids = matches[0]

for i in range(len(token_ids)):
  if pattern_peinture[i]["RIGHT_ID"] == 'agent':
    print(q2_prep[token_ids[i]].text)
# Out:
# [(11010221642568005822, [5, 6, 8])]
# qui

# %%
#  Apply the pattern to each sentence of this document, do you find the right answer?

def answer( doc, matcher):
  answers = []
  for sent in doc.sents:
    matches = matcher(sent)

    for match_id, tok_id in matches:
      for idx,i in enumerate(tok_id[:]):
        pattern_part = pattern_peinture[idx]
        text = sent[i].text
        if pattern_part["RIGHT_ID"]=="agent":
          answers.append(text)
  return answers

answers = answer( documents_prep[id_doc], matcher)
print("Réponses possibles: ")
print("-"+"\n-".join(answers))
# Out:
# Réponses possibles:
# -Théodore Géricault

# %% [markdown]
# **Exercise 14:** Use the patterns defined to find the answers to the questions below. Here, we know that we're looking for the painter, we don'y want to match the question to the answer, we want to test known patterns to find the right answer.
#
# - find a way to extract the name of the painting from the question
# - retrieve the relevant document
# - test the patterns defined previously to extract the correct answer

# %%
new_questions = [
    'Qui a peint American Gothic ?',
    'Qui est l\'auteur de la peinture La Nuit étoilée',
    'Qui a réalisé Un Garrochista ?',
]

# %%
# Search entities in the question (there should be only one..)
q2ents = {}
for i,q in enumerate( new_questions ):
  q2ents[i] = []
  qp = nlp( q )
  for ent in qp.ents:
    q2ents[i].append( ent )
print(q2ents)
# Out:
# {0: [American Gothic], 1: [La Nuit étoilée], 2: [Un Garrochista]}

# %%
# Retrive document
q2doc = {}
for q in q2ents.keys():
  for ent in q2ents[q]:
    matching_docs = retrieve_documents(documents_prep, index, ent.text)
    id_doc = matching_docs[0]
    q2doc[q] = id_doc
    print( 'Q',q, ent.text, 'Doc', q2doc[q])
# Out:
# Q 0 American Gothic Doc 3
# Q 1 La Nuit étoilée Doc 2
# Q 2 Un Garrochista Doc 7

# %%
# Test the documents against several patterns

matcher = DependencyMatcher(nlp.vocab)
matcher.add("PAINTER", [pattern_tableau, pattern_peinture])

def answer( doc_prep, matcher):
  answers = []
  for sent in doc_prep.sents:
    matches = matcher(sent)

    for match_id, tok_id in matches:
      for idx,i in enumerate(tok_id[:]):
        try:
          pattern_part = pattern_tableau[idx]
          text = sent[i].text
          if pattern_part["RIGHT_ID"] in ["mod"]:
            print(text)
            answers.append(text)
        except:
          print("")

        try:
          pattern_part = pattern_peinture[idx]
          text = sent[i].text
          if pattern_part["RIGHT_ID"] in ["agent"]:
            answers.append(text)
        except:
          print("")

  return answers
for q in q2ents:
  print( "\nQ", q, "Tableau:", q2ents[q] )
  answers = answer( documents_prep[q2doc[q]], matcher)
  print("Réponses possibles: ")
  print("-"+"\n-".join(answers))
# Out:
# Q 0 Tableau: [American Gothic]
# Grant Wood
# Réponses possibles:
# -Grant Wood
#
# Q 1 Tableau: [La Nuit étoilée]
# réalisée
#
# Réponses possibles:
# -réalisée
# -Vincent van Gogh
#
# Q 2 Tableau: [Un Garrochista]
# réalisée
#
# Réponses possibles:
# -réalisée
# -Francisco de Goya

# %%
sentences = documents_prep[7].sents
displacy.render(list(sentences)[0], style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="52e0ec2cacf44458b8ad6471fcaf1ba7-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Un Garrochista</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">une</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">peinture</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">réalisée</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">par</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Francisco de Goya</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">1795.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl:agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-7" stroke-width="2px" d="M770,264.5 C770,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-52e0ec2cacf44458b8ad6471fcaf1ba7-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl:mod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>
